# %%
# %load_ext rpy2.ipython

# %%
# %%R
# workDir = '/home/chantal/Chazy/Bulk/ITS/data/'
# figDir = '/home/chantal/Chazy/Bulk/ITS/figs/'
#
# physeqDir = '/home/chantal/Chazy/data/phyloseq/ITS/'
# physeqBulk = 'bulk-core'
#
#
# nprocs = 20

# %%
# %%R
# library(phyloseq)
# library(tidyr)
# library(plyr); library(dplyr)
# library(DESeq2)
# library(foreach)
# library(doParallel)
# library(ggplot2)
# library(gridExtra)
# library(reshape2)
# library(RColorBrewer)
# Out:
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning:
# Attaching package: ‘dplyr’
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following objects are masked from ‘package:plyr’:
#
#     arrange, count, desc, failwith, id, mutate, rename, summarise,
#     summarize
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Loading required package: S4Vectors
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Loading required package: stats4
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Loading required package: BiocGenerics
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Loading required package: parallel
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning:
# Attaching package: ‘BiocGenerics’
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following objects are masked from ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following objects are masked from ‘package:stats’:
#
#     IQR, mad, xtabs
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, as.vector, cbind, colnames,
#     do.call, duplicated, eval, evalq, Filter, Find, get, grep, grepl,
#     intersect, is.unsorted, lapply, lengths, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unlist, unsplit
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning:
# Attaching package: ‘S4Vectors’
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following object is masked from ‘package:dplyr’:
#
#     rename
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following object is masked from ‘package:plyr’:
#
#     rename
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Loading required package: IRanges
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning:
# Attaching package: ‘IRanges’
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following objects are masked from ‘package:dplyr’:
#
#     collapse, desc, slice
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following object is masked from ‘package:plyr’:
#
#     desc
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following object is masked from ‘package:tidyr’:
#
#     expand
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following object is masked from ‘package:phyloseq’:
#
#     distance
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Loading required package: GenomicRanges
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Loading required package: GenomeInfoDb
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Loading required package: SummarizedExperiment
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Loading required package: Biobase
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning:
# Attaching package: ‘Biobase’
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following object is masked from ‘package:phyloseq’:
#
#     sampleNames
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Loading required package: Rcpp
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Loading required package: RcppArmadillo
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: foreach: simple, scalable parallel programming from Revolution Analytics
# Use Revolution R for scalability, fault tolerance and more.
# http://www.revolutionanalytics.com
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Loading required package: iterators
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning:
# Attaching package: ‘gridExtra’
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following object is masked from ‘package:Biobase’:
#
#     combine
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following object is masked from ‘package:BiocGenerics’:
#
#     combine
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: The following object is masked from ‘package:dplyr’:
#
#     combine
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)

# %% [markdown]
# #### Read in sample metadata and OTU table

# %%
# %%R
#
# F = file.path(physeqDir, physeqBulk)
# print(F)
# physeq.Bulk = readRDS(F)
# physeq.Bulk.m = physeq.Bulk %>% sample_data
# physeq.Bulk = prune_samples((physeq.Bulk.m$Land_Management != "PAS" & !(is.na(physeq.Bulk.m$Soil_Temp))),
#                            physeq.Bulk)
# physeq.Bulk.m = physeq.Bulk %>% sample_data
#
# physeq.Bulk = subset_taxa(physeq.Bulk, Rank1=="k__Fungi")
# physeq.Bulk.m = physeq.Bulk %>% sample_data
#
#
#
# physeq.Bulk
# Out:
# [1] "/home/chantal/Chazy/data/phyloseq/ITS//bulk-core"
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 2247 taxa and 128 samples ]
# sample_data() Sample Data:       [ 128 samples by 24 sample variables ]
# tax_table()   Taxonomy Table:    [ 2247 taxa by 7 taxonomic ranks ]

# %%
# %%R
# get_l2fc = function(physeq.obj, Land_Management, sparsity_threshold) {
#
#     physeq.Bulk.m = physeq.obj %>% sample_data
#
#     p = prune_samples((physeq.Bulk.m$Land_Management == Land_Management),
#                            physeq.Bulk)
#
#
#     p = filter_taxa(p, function(x) sum(x > 0) > sparsity_threshold * length(x), TRUE)
#
#     dds = phyloseq_to_deseq2(p, ~ Soil_Temp)
#     dds = DESeq(dds, quiet = TRUE, fitType = "local")
#
#     theta = 1
#     r = results(dds, independentFiltering = FALSE)
#     r$OTU = rownames(r)
#
#     d = data.frame(r[, c("OTU","log2FoldChange", "lfcSE", "padj")])
#
#    # d$padj = p.adjust(p, method = "BH")
#     TT = data.frame(tax_table(p))
#     TT$OTU = rownames(TT)
#     d = left_join(d, TT)
#
#
#     d
# }

# %%
# %%R
#
# sdm = physeq.Bulk %>% sample_data %>%
#     filter(! is.na(Till)) %>%
#     select(Land_Management) %>%
#    distinct() %>%
#     arrange(Land_Management)
#
#
# sdm
# Out:
#   Land_Management
# 1             NTH
# 2             NTR
# 3             PTH
# 4             PTR

# %%
# %%R
# # adding range of sparsity thresholds (all pairwise)
# sdms = sdm %>%
#     unite(sdm, Land_Management, sep='___')
#
# sdms = expand.grid(sdms$sdm,
#                     sparsity_threshold = seq(0.05,0.95,0.05)) %>%
#     separate(Var1, c('Land_Management'), sep='___')
#
#
# cat('Number of pairwise combinations of variables:', sdms %>% nrow, '\n\n')
# head(sdms)
# Out:
# Number of pairwise combinations of variables: 76
#
#   Land_Management sparsity_threshold
# 1             NTH               0.05
# 2             NTR               0.05
# 3             PTH               0.05
# 4             PTR               0.05
# 5             NTH               0.10
# 6             NTR               0.10

# %%
# %%R
# registerDoParallel(8)
#
# df.l2fc = tbl_df(mdply(sdms,
#                        get_l2fc,
#                        .parallel = TRUE,
#                        physeq.obj = physeq.Bulk))
# df.l2fc
# Out:
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: converting counts to integer mode
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: converting counts to integer mode
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: converting counts to integer mode
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: converting counts to integer mode
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: converting counts to integer mode
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: converting counts to integer mode
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: converting counts to integer mode
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: converting counts to integer mode
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Joining by: "OTU"
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Joining by: "OTU"
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Joining by: "OTU"
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Joining by: "OTU"
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Joining by: "OTU"
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Joining by: "OTU"
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Joining by: "OTU"
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Joining by: "OTU"
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# Source: local data frame [15,444 x 13]
#
#    Land_Management sparsity_threshold       OTU log2FoldChange      lfcSE
#              (chr)              (dbl)     (chr)          (dbl)      (dbl)
# 1              NTH               0.05  OTU.6089    0.088821402 0.06314356
# 2              NTH               0.05 OTU.17326   -0.031651009 0.06016730
# 3              NTH               0.05 OTU.14908    0.107269419 0.06428139
# 4              NTH               0.05  OTU.6041    0.019694265 0.06482397
# 5              NTH               0.05  OTU.6291    0.016688431 0.06047114
# 6              NTH               0.05  OTU.9364   -0.067445540 0.06442104
# 7              NTH               0.05   OTU.586    0.047062790 0.05408304
# 8              NTH               0.05 OTU.19007    0.026198753 0.05905875
# 9              NTH               0.05 OTU.36383   -0.030097304 0.05846607
# 10             NTH               0.05  OTU.1470    0.004400169 0.04245722
# ..             ...                ...       ...            ...        ...
# Variables not shown: padj (dbl), Rank1 (fctr), Rank2 (fctr), Rank3 (fctr),
#   Rank4 (fctr), Rank5 (fctr), Rank6 (fctr), Rank7 (fctr)

# %%
# %%R
# summarise(df.l2fc,
#   meanl2fc = mean(log2FoldChange, na.rm = TRUE))
# Out:
# Source: local data frame [1 x 1]
#
#      meanl2fc
#         (dbl)
# 1 -0.01870906

# %%
# %%R
# summarise(df.l2fc,
#   sdl2fc = sd(log2FoldChange, na.rm = TRUE))
# Out:
# Source: local data frame [1 x 1]
#
#       sdl2fc
#        (dbl)
# 1 0.07273847

# %%
# %%R
# df.l2fc$padj2 = p.adjust(df.l2fc$padj, method = "BH")

# %%
# %%R
# df.l2fc$Temp[df.l2fc$log2FoldChange > 0] = "increasing"
# df.l2fc$Temp[df.l2fc$log2FoldChange <0] = "decreasing"

# %%
# %%R
# write.table(df.l2fc, "data/l2fc_TempCompiled", row.names = FALSE, sep = ",")

# %%
# %%R
# df.l2fc = read.table('data/l2fc_TempCompiled', sep =',', header = TRUE)

# %%
# %%R
# head(df.l2fc)
# Out:
#   Land_Management sparsity_threshold       OTU log2FoldChange      lfcSE
# 1             NTH               0.05  OTU.6089     0.08882140 0.06314356
# 2             NTH               0.05 OTU.17326    -0.03165101 0.06016730
# 3             NTH               0.05 OTU.14908     0.10726942 0.06428139
# 4             NTH               0.05  OTU.6041     0.01969426 0.06482397
# 5             NTH               0.05  OTU.6291     0.01668843 0.06047114
# 6             NTH               0.05  OTU.9364    -0.06744554 0.06442104
#        padj    Rank1            Rank2             Rank3           Rank4
# 1 0.9640580 k__Fungi  p__unidentified   c__unidentified o__unidentified
# 2 0.9945518 k__Fungi p__Basidiomycota c__Agaricomycetes    o__Boletales
# 3 0.8286571 k__Fungi p__Basidiomycota c__Agaricomycetes   o__Agaricales
# 4 0.9945518 k__Fungi p__Basidiomycota c__Agaricomycetes   o__Agaricales
# 5 0.9945518 k__Fungi p__Basidiomycota c__Agaricomycetes   o__Agaricales
# 6 0.9945518 k__Fungi p__Basidiomycota c__Agaricomycetes    o__Boletales
#                Rank5           Rank6                       Rank7     padj2
# 1    f__unidentified g__unidentified                 s__Fungi sp 0.9999868
# 2 f__Boletinellaceae g__Boletinellus s__Boletinellus merulioides 0.9999868
# 3    f__Bolbitiaceae     g__Conocybe    s__Conocybe siennophylla 0.9999868
# 4     f__Agaricaceae   g__Lycoperdon                        <NA> 0.9999868
# 5     f__Agaricaceae   g__Lycoperdon                        <NA> 0.9999868
# 6               <NA>            <NA>                        <NA> 0.9999868
#         Temp
# 1 increasing
# 2 decreasing
# 3 increasing
# 4 increasing
# 5 increasing
# 6 decreasing

# %%
# %%R
# r = filter(df.l2fc, padj2 <=0.10)
# print(length(unique(r$OTU)))
# print(length(df.l2fc$OTU))
# Out:
# [1] 44
# [1] 15444

# %%
# %%R
#
# padj.cutoff = 0.10
#
# df.l2fc.rejH = df.l2fc %>%
#     filter(padj2 <= padj.cutoff) %>%
#     group_by(sparsity_threshold, Land_Management) %>%
#     summarize(n_reject_hypo = n()) %>%
#     ungroup
#
# df.l2fc.rejH %>% head(n=6)
# Out:
# Source: local data frame [6 x 3]
#
#   sparsity_threshold Land_Management n_reject_hypo
#                (dbl)          (fctr)         (int)
# 1               0.05             NTH             3
# 2               0.05             NTR            28
# 3               0.05             PTH             2
# 4               0.05             PTR             1
# 5               0.10             NTH             6
# 6               0.10             NTR            33

# %%
# %%R
#
# padj.cutoff = 0.10
#
# df.l2fc.rejH.s = df.l2fc %>%
#     filter(padj2 < padj.cutoff) %>%
#     group_by(sparsity_threshold, Land_Management) %>%
#     summarize(n_reject_hypo = n()) %>%
#     ungroup
#
# df.l2fc.rejH.s %>%  as.data.frame
# Out:
#    sparsity_threshold Land_Management n_reject_hypo
# 1                0.05             NTH             3
# 2                0.05             NTR            28
# 3                0.05             PTH             2
# 4                0.05             PTR             1
# 5                0.10             NTH             6
# 6                0.10             NTR            33
# 7                0.10             PTH             2
# 8                0.10             PTR             1
# 9                0.15             NTH             5
# 10               0.15             NTR            35
# 11               0.15             PTH             2
# 12               0.15             PTR             1
# 13               0.20             NTH             6
# 14               0.20             NTR            36
# 15               0.20             PTH             2
# 16               0.20             PTR             1
# 17               0.25             NTH             6
# 18               0.25             NTR            36
# 19               0.25             PTH             2
# 20               0.25             PTR             2
# 21               0.30             NTH             5
# 22               0.30             NTR            34
# 23               0.30             PTH             2
# 24               0.30             PTR             2
# 25               0.35             NTH             5
# 26               0.35             NTR            29
# 27               0.35             PTH             2
# 28               0.35             PTR             2
# 29               0.40             NTH             4
# 30               0.40             NTR            24
# 31               0.40             PTH             2
# 32               0.40             PTR             2
# 33               0.45             NTH             1
# 34               0.45             NTR            18
# 35               0.45             PTH             2
# 36               0.45             PTR             2
# 37               0.50             NTR            14
# 38               0.50             PTH             2
# 39               0.50             PTR             2
# 40               0.55             NTR            13
# 41               0.55             PTH             2
# 42               0.55             PTR             2
# 43               0.60             NTR            11
# 44               0.60             PTH             1
# 45               0.60             PTR             1
# 46               0.65             NTR             9
# 47               0.65             PTH             1
# 48               0.65             PTR             1
# 49               0.70             NTR             8
# 50               0.70             PTH             1
# 51               0.70             PTR             1
# 52               0.75             NTR             8
# 53               0.75             PTH             1
# 54               0.75             PTR             1
# 55               0.80             NTR             6
# 56               0.80             PTH             1
# 57               0.80             PTR             1
# 58               0.85             NTR             6
# 59               0.85             PTH             1
# 60               0.85             PTR             1
# 61               0.90             NTR             5
# 62               0.90             PTH             1
# 63               0.90             PTR             1
# 64               0.95             NTR             1
# 65               0.95             PTR             1

# %%
# %%R
# # max number of rejected hypos
# max.rejH = df.l2fc.rejH.s %>%
#     arrange(desc(n_reject_hypo)) %>%
#     head(n=1)
# max.rejH = max.rejH$sparsity_threshold
# max.rejH
# Out:
# [1] 0.2

# %%
# %%R -w 450 -h 400
#
# ggplot(df.l2fc.rejH.s, aes(sparsity_threshold, n_reject_hypo, color = Land_Management))+
#     geom_point(size=3) +
#     geom_vline(xintercept=max.rejH, linetype='dashed', alpha=0.5) +
#     labs(x='Sparsity threshold', y='Number of rejected hypotheses') +
#     theme_bw() +
#     theme(
#         text = element_text(size=18),
#         axis.title.y = element_text(vjust=1)
#         )

# %%
# %%R
# df.l2fc.f = df.l2fc %>%
#     filter(sparsity_threshold == 0.15)
#
# df.l2fc.f %>% nrow
# Out:
# [1] 1627

# %%
# %%R #-i workDir
# # Writing out l2fc table
#
# outFile = 'data/l2fc_Temp.txt'
# write.table(df.l2fc.f, 'data/l2fc_Temp.txt', sep='\t', quote=FALSE, row.names=FALSE)

# %%
# %%R
# df.l2fc = read.table('data/l2fc_Temp.txt', sep='\t', header = TRUE)

# %%
# %%R
# df.l2fc$Rank2 = gsub("p__", "", df.l2fc$Rank2)
# df.l2fc$Rank3 = gsub("c__", "", df.l2fc$Rank3)
# df.l2fc$Rank4 = gsub("o__", "", df.l2fc$Rank4)
# df.l2fc$Rank5 = gsub("f__", "", df.l2fc$Rank5)
# df.l2fc$Rank6 = gsub("g__", "", df.l2fc$Rank6)
# df.l2fc$Rank7 = gsub("s__", "", df.l2fc$Rank7)

# %%
# %%R
# print(length(df.l2fc$OTU))
# print(length(unique(df.l2fc$OTU)))
# Out:
# [1] 1627
# [1] 635

# %%
# %%R
# resp = df.l2fc %>% filter(padj2 <=0.10) %>% group_by(Temp, Land_Management) %>% summarise(resp = n())
# resp %>% as.data.frame
# Out:
#         Temp Land_Management resp
# 1 decreasing             NTH    5
# 2 decreasing             NTR   34
# 3 decreasing             PTH    2
# 4 decreasing             PTR    1
# 5 increasing             NTR    1

# %%
# %%R
# resp = df.l2fc %>% ungroup %>% group_by(Temp, Land_Management) %>% filter(padj2 <=0.10) %>% group_by(Temp, Land_Management,
#                                                                                                      Rank3) %>%
#         summarise(resp = n()) %>% ungroup %>% arrange(Rank3, -resp)
# resp %>% as.data.frame
# Out:
#          Temp Land_Management              Rank3 resp
# 1  decreasing             NTR    Dothideomycetes   17
# 2  decreasing             NTR      Leotiomycetes    2
# 3  decreasing             NTH      Leotiomycetes    1
# 4  decreasing             NTR Microbotryomycetes    1
# 5  decreasing             NTR    Sordariomycetes    3
# 6  decreasing             PTH    Sordariomycetes    1
# 7  increasing             NTR    Sordariomycetes    1
# 8  decreasing             NTR    Tremellomycetes    6
# 9  decreasing             NTH    Tremellomycetes    2
# 10 decreasing             PTH    Tremellomycetes    1
# 11 decreasing             PTR    Tremellomycetes    1
# 12 decreasing             NTH       unidentified    1
# 13 decreasing             NTR       unidentified    1
# 14 decreasing             NTR               <NA>    4
# 15 decreasing             NTH               <NA>    1

# %%
# %%R
# resp = df.l2fc %>% group_by(OTU) %>% filter(padj2 <=0.10) %>%
#         summarise(resp = n()) %>% filter(resp >1)
#
# print(resp %>% as.data.frame)
# filter(df.l2fc, OTU %in% resp$OTU & padj <=0.10) %>% arrange(OTU)
# Out:
#        OTU resp
# 1 OTU.1177    2
# 2 OTU.1851    2
# 3  OTU.549    4
# 4  OTU.692    2
#    Land_Management sparsity_threshold      OTU log2FoldChange      lfcSE
# 1              NTH               0.15 OTU.1177     -0.2024174 0.04713324
# 2              NTR               0.15 OTU.1177     -0.2928592 0.05173789
# 3              NTH               0.15 OTU.1851     -0.2038657 0.04527681
# 4              NTR               0.15 OTU.1851     -0.2910187 0.06009588
# 5              NTH               0.15  OTU.549     -0.2885179 0.05085006
# 6              NTR               0.15  OTU.549     -0.3546516 0.06936023
# 7              PTH               0.15  OTU.549     -0.2104432 0.04045437
# 8              PTR               0.15  OTU.549     -0.3275271 0.04794908
# 9              NTH               0.15  OTU.692     -0.2589236 0.04523613
# 10             NTR               0.15  OTU.692     -0.2148992 0.05674922
#            padj    Rank1         Rank2           Rank3        Rank4
# 1  1.907773e-03 k__Fungi Basidiomycota Tremellomycetes  Tremellales
# 2  9.253218e-07 k__Fungi Basidiomycota Tremellomycetes  Tremellales
# 3  9.753418e-04 k__Fungi    Ascomycota            <NA>         <NA>
# 4  4.229579e-05 k__Fungi    Ascomycota            <NA>         <NA>
# 5  3.042979e-06 k__Fungi Basidiomycota Tremellomycetes unidentified
# 6  1.197114e-05 k__Fungi Basidiomycota Tremellomycetes unidentified
# 7  4.455903e-05 k__Fungi Basidiomycota Tremellomycetes unidentified
# 8  3.176653e-09 k__Fungi Basidiomycota Tremellomycetes unidentified
# 9  3.042979e-06 k__Fungi    Ascomycota   Leotiomycetes   Helotiales
# 10 1.983621e-03 k__Fungi    Ascomycota   Leotiomycetes   Helotiales
#             Rank5         Rank6              Rank7        padj2       Temp
# 1  Incertae sedis     Dioszegia               <NA> 6.921584e-02 decreasing
# 2  Incertae sedis     Dioszegia               <NA> 1.230966e-04 decreasing
# 3            <NA>          <NA>               <NA> 3.959754e-02 decreasing
# 4            <NA>          <NA>               <NA> 2.903168e-03 decreasing
# 5    unidentified  unidentified Tremellomycetes sp 3.112007e-04 decreasing
# 6    unidentified  unidentified Tremellomycetes sp 9.754878e-04 decreasing
# 7    unidentified  unidentified Tremellomycetes sp 3.017736e-03 decreasing
# 8    unidentified  unidentified Tremellomycetes sp 6.454112e-07 decreasing
# 9     Helotiaceae Hymenoscyphus               <NA> 3.112007e-04 decreasing
# 10    Helotiaceae Hymenoscyphus               <NA> 7.137455e-02 decreasing

# %%
# %%R
# df.l2fc %>% filter(padj2 <=0.10) %>% ungroup %>% group_by(Temp) %>%
#         summarise(mean_l2fc = mean(log2FoldChange), sd_l2fc = sd(log2FoldChange))
# Out:
# Source: local data frame [2 x 3]
#
#         Temp  mean_l2fc   sd_l2fc
#       (fctr)      (dbl)     (dbl)
# 1 decreasing -0.2754123 0.0606254
# 2 increasing  0.2013986        NA

# %%
# %%R -w 1000 -h 500
# d = df.l2fc
# FDR = 0.10
#
# d$Rank2 = as.character(d$Rank2)
# d$Rank2[is.na(d$Rank2)] = "unclassified"
# d$Rank2 = factor(d$Rank2)
#
# max.l2fc = ddply(d, .(Rank2), summarize, M = max(log2FoldChange))
# d$Rank2 = factor(d$Rank2, max.l2fc[order(-max.l2fc$M),]$Rank2)
#
# M = max(as.numeric(d$Rank2), na.rm = TRUE) + 1
# d$x = as.numeric(d$Rank2)
# d$x[is.na(d$x)] = M
# d$x.jitter = d$x + runif(length(d$x), -1, 1) * 0.2
#
# colourCount = length(unique(d$Rank2)) + 1
# getPalette = colorRampPalette(brewer.pal(10, "Dark2"))
#
# p = ggplot(d, aes(x = x.jitter, y = log2FoldChange, color = Rank2))
# p = p + facet_grid(~Land_Management)
#
# p = p + geom_point(alpha = 1.00, shape = 21, size = 1.5)
#
# p = p + scale_color_manual(values = getPalette(colourCount))
#
# p = p + geom_point(data = subset(d, padj2 <= FDR), color = "black", shape = 4, size = 2)
#
# #p = p + geom_hline(y = 1.3)
#
# p = p + theme_bw()
#
# p = p + theme(axis.text.x = element_blank())
#
# p = p + labs(x = "Phylum", color = "Phylum")
#
# p = p + guides(col = guide_legend(ncol = 2))
#
# p = p + labs(y = expression(paste("", log[2]," Fold Change",sep="")))
#
# p = p + guides(colour = guide_legend(override.aes = list(size=4)))
#
# p

# %%
# %%R -w 1200 -h 600
# d = df.l2fc
# FDR = 0.10
#
# d$Rank3 = as.character(d$Rank3)
# d$Rank3[is.na(d$Rank3)] = "unclassified"
# d$Rank3 = factor(d$Rank3)
#
# max.l2fc = ddply(d, .(Rank3), summarize, M = max(log2FoldChange))
# d$Rank3 = factor(d$Rank3, max.l2fc[order(-max.l2fc$M),]$Rank3)
#
# M = max(as.numeric(d$Rank3), na.rm = TRUE) + 1
# d$x = as.numeric(d$Rank3)
# d$x[is.na(d$x)] = M
# d$x.jitter = d$x + runif(length(d$x), -1, 1) * 0.2
#
# colourCount = length(unique(d$Rank3)) + 1
# getPalette = colorRampPalette(brewer.pal(10, "Dark2"))
#
# p = ggplot(d, aes(x = x.jitter, y = log2FoldChange, color = Rank3))
# p = p + facet_wrap(~Land_Management, ncol = 2)
#
# p = p + geom_point(alpha = 1.00, shape = 19, size = 3)
#
# p = p + scale_color_manual(values = getPalette(colourCount))
#
# p = p + geom_point(data = subset(d, padj2 <= FDR), color = "white", shape = 19, size = 1)
#
# #p = p + geom_hline(y = 1.3)
#
# #p = p + theme_bw()
#
# p = p + labs(x = "Class", color = "Class")
#
# p = p + guides(col = guide_legend(ncol = 2))
#
# p = p + labs(y = expression(paste("", log[2]," Fold Change",sep="")))
#
# p = p + guides(colour = guide_legend(override.aes = list(size=6))) +
#         theme(text = element_text(size=14), axis.text.x = element_text(angle=90, vjust=1))
#
# p = p + theme(axis.text.x = element_blank())
#
#
#
# p

# %%
# %%R
# r = df.l2fc %>% group_by(OTU, Land_Management,Temp) %>% filter(padj2 <=0.10) %>% arrange(OTU) %>% select(OTU,
#                                                                                         Rank3,Rank4, Rank5, Rank6, Rank7)
# r %>% as.data.frame()
# Out:
#    Land_Management       Temp       OTU              Rank3               Rank4
# 1              NTR decreasing  OTU.1001    Dothideomycetes        Pleosporales
# 2              NTR decreasing  OTU.1035    Dothideomycetes         Capnodiales
# 3              NTR decreasing  OTU.1060      Leotiomycetes          Helotiales
# 4              NTH decreasing  OTU.1177    Tremellomycetes         Tremellales
# 5              NTR decreasing  OTU.1177    Tremellomycetes         Tremellales
# 6              NTH decreasing  OTU.1297       unidentified        unidentified
# 7              NTR decreasing   OTU.145    Dothideomycetes        Pleosporales
# 8              NTR decreasing  OTU.1649    Tremellomycetes         Tremellales
# 9              NTR decreasing   OTU.169    Dothideomycetes        unidentified
# 10             NTH decreasing  OTU.1851               <NA>                <NA>
# 11             NTR decreasing  OTU.1851               <NA>                <NA>
# 12             NTR decreasing  OTU.1989    Dothideomycetes                <NA>
# 13             NTR decreasing   OTU.214    Dothideomycetes         Capnodiales
# 14             NTR decreasing  OTU.2221    Dothideomycetes         Capnodiales
# 15             NTR decreasing   OTU.226    Tremellomycetes         Tremellales
# 16             PTH decreasing   OTU.227    Sordariomycetes         Sordariales
# 17             NTR decreasing  OTU.2289    Sordariomycetes          Xylariales
# 18             NTR decreasing  OTU.2369    Tremellomycetes         Tremellales
# 19             NTR decreasing OTU.23714    Dothideomycetes                <NA>
# 20             NTR decreasing  OTU.2499    Sordariomycetes         Hypocreales
# 21             NTR decreasing    OTU.25               <NA>                <NA>
# 22             NTR decreasing    OTU.26       unidentified        unidentified
# 23             NTR decreasing  OTU.2624    Tremellomycetes Cystofilobasidiales
# 24             NTR decreasing  OTU.2719 Microbotryomycetes     Sporidiobolales
# 25             NTR decreasing OTU.27312    Dothideomycetes                <NA>
# 26             NTR decreasing OTU.37716    Dothideomycetes                <NA>
# 27             NTR decreasing   OTU.388               <NA>                <NA>
# 28             NTR decreasing  OTU.4234    Dothideomycetes                <NA>
# 29             NTR decreasing OTU.52983    Dothideomycetes                <NA>
# 30             NTH decreasing   OTU.549    Tremellomycetes        unidentified
# 31             NTR decreasing   OTU.549    Tremellomycetes        unidentified
# 32             PTH decreasing   OTU.549    Tremellomycetes        unidentified
# 33             PTR decreasing   OTU.549    Tremellomycetes        unidentified
# 34             NTR decreasing OTU.63543    Dothideomycetes                <NA>
# 35             NTR decreasing OTU.64249    Dothideomycetes                <NA>
# 36             NTR decreasing   OTU.655    Dothideomycetes        Pleosporales
# 37             NTR decreasing   OTU.657               <NA>                <NA>
# 38             NTR decreasing    OTU.66    Dothideomycetes        Pleosporales
# 39             NTH decreasing   OTU.692      Leotiomycetes          Helotiales
# 40             NTR decreasing   OTU.692      Leotiomycetes          Helotiales
# 41             NTR increasing   OTU.788    Sordariomycetes         Sordariales
# 42             NTR decreasing   OTU.892    Dothideomycetes        Pleosporales
# 43             NTR decreasing    OTU.92    Sordariomycetes          Xylariales
#                 Rank5          Rank6                    Rank7
# 1        unidentified   unidentified          Pleosporales sp
# 2  Mycosphaerellaceae   unidentified    Mycosphaerellaceae sp
# 3     Hyaloscyphaceae           <NA>                     <NA>
# 4      Incertae sedis      Dioszegia                     <NA>
# 5      Incertae sedis      Dioszegia                     <NA>
# 6        unidentified   unidentified            Ascomycota sp
# 7       Pleosporaceae           <NA>                     <NA>
# 8      Incertae sedis        Bullera       Bullera globospora
# 9        unidentified   unidentified       Dothideomycetes sp
# 10               <NA>           <NA>                     <NA>
# 11               <NA>           <NA>                     <NA>
# 12               <NA>           <NA>                     <NA>
# 13               <NA>           <NA>                     <NA>
# 14 Mycosphaerellaceae           <NA>                     <NA>
# 15     Incertae sedis      Hannaella                     <NA>
# 16  Lasiosphaeriaceae   unidentified     Lasiosphaeriaceae sp
# 17     Incertae sedis           <NA>                     <NA>
# 18     Incertae sedis   Cryptococcus   Cryptococcus victoriae
# 19               <NA>           <NA>                     <NA>
# 20        Nectriaceae           <NA>                     <NA>
# 21               <NA>           <NA>                     <NA>
# 22       unidentified   unidentified                 Fungi sp
# 23     Incertae sedis      Mrakiella       Mrakiella aquatica
# 24     Incertae sedis Sporobolomyces Sporobolomyces oryzicola
# 25               <NA>           <NA>                     <NA>
# 26               <NA>           <NA>                     <NA>
# 27               <NA>           <NA>                     <NA>
# 28               <NA>           <NA>                     <NA>
# 29               <NA>           <NA>                     <NA>
# 30       unidentified   unidentified       Tremellomycetes sp
# 31       unidentified   unidentified       Tremellomycetes sp
# 32       unidentified   unidentified       Tremellomycetes sp
# 33       unidentified   unidentified       Tremellomycetes sp
# 34               <NA>           <NA>                     <NA>
# 35               <NA>           <NA>                     <NA>
# 36  Leptosphaeriaceae  Leptosphaeria                     <NA>
# 37               <NA>           <NA>                     <NA>
# 38     Incertae sedis           <NA>                     <NA>
# 39        Helotiaceae  Hymenoscyphus                     <NA>
# 40        Helotiaceae  Hymenoscyphus                     <NA>
# 41  Lasiosphaeriaceae  Schizothecium                     <NA>
# 42     Incertae sedis           <NA>                     <NA>
# 43     Incertae sedis   Microdochium          Microdochium sp

# %%
# %%R
# unique(r$Rank3)
# Out:
# [1] "Dothideomycetes"    "Leotiomycetes"      "Tremellomycetes"
# [4] "unidentified"       NA                   "Sordariomycetes"
# [7] "Microbotryomycetes"

# %%
# %%R
# df.l2fc %>% filter(padj2 <=0.10, Land_Management == 'NTR') %>% group_by(Temp, Rank3, Rank2, Rank4) %>%
#         summarise(counts = n()) %>% ungroup %>% arrange(Rank3, -counts) %>% as.data.frame()
# Out:
#          Temp              Rank3         Rank2               Rank4 counts
# 1  decreasing    Dothideomycetes    Ascomycota                <NA>      8
# 2  decreasing    Dothideomycetes    Ascomycota        Pleosporales      5
# 3  decreasing    Dothideomycetes    Ascomycota         Capnodiales      3
# 4  decreasing    Dothideomycetes    Ascomycota        unidentified      1
# 5  decreasing      Leotiomycetes    Ascomycota          Helotiales      2
# 6  decreasing Microbotryomycetes Basidiomycota     Sporidiobolales      1
# 7  decreasing    Sordariomycetes    Ascomycota          Xylariales      2
# 8  decreasing    Sordariomycetes    Ascomycota         Hypocreales      1
# 9  increasing    Sordariomycetes    Ascomycota         Sordariales      1
# 10 decreasing    Tremellomycetes Basidiomycota         Tremellales      4
# 11 decreasing    Tremellomycetes Basidiomycota Cystofilobasidiales      1
# 12 decreasing    Tremellomycetes Basidiomycota        unidentified      1
# 13 decreasing       unidentified  unidentified        unidentified      1
# 14 decreasing               <NA>    Ascomycota                <NA>      3
# 15 decreasing               <NA>          <NA>                <NA>      1

# %%
# %%R
# ggsave(filename = "data/figs/OTUs_Temp.png", plot = p, width =12, height =6)

# %%
# %%R -w 400 -h 400
# p = ggplot(data = resp, aes(x = Temp, y = resp, fill = Temp)) +
#     geom_bar(stat = 'identity') +
#     theme(text = element_text(size=16)) + ylab("Number of Enriched OTUs") + scale_x_discrete(breaks=NULL)
# p
# Out:
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Error in eval(expr, envir, enclos) : object 'Temp' not found
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: In addition:
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: Warning messages:
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: 1: replacing previous import ‘BiocGenerics::Position’ by ‘ggplot2::Position’ when loading ‘phyloseq’
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: 2:
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: In class(x) <- c("tbl_df", "tbl", "data.frame") :
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning:
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning:  Setting class(x) to multiple strings ("tbl_df", "tbl", ...); result will no longer be an S4 object
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: 3:
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: In brewer.pal(10, "Dark2") :
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning:  n too large, allowed maximum for palette Dark2 is 8
# Returning the palette you asked for with that many colors
#
#
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.py:106: UserWarning: 4:
#   res = super(Function, self).__call__(*new_args, **new_kwargs)
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# <ipython-input-36-6bc33b5ec3d2> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'R', u'-w 400 -h 400', u'p = ggplot(data = resp, aes(x = Temp, y = resp, fill = Temp)) +\n    geom_bar(stat = \'identity\') + \n    theme(text = element_text(size=16)) + ylab("Number of Enriched OTUs") + scale_x_discrete(breaks=NULL)\np')
#
# /opt/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2291             magic_arg_s = self.var_expand(line, stack_depth)
#    2292             with self.builtin_trap:
# -> 2293                 result = fn(magic_arg_s, cell)
#    2294             return result
#    2295
#
# /opt/anaconda/lib/python2.7/site-packages/rpy2/ipython/rmagic.pyc in R(self, line, cell, local_ns)
#
# /opt/anaconda/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /opt/anaconda/lib/python2.7/site-packages/rpy2/ipython/rmagic.pyc in R(self, line, cell, local_ns)
#     659                     old_writeconsole_regular = ri.get_writeconsole_regular()
#     660                     ri.set_writeconsole_regular(self.write_console_regular)
# --> 661                     ro.r.show(result)
#     662                     text_output += self.flush()
#     663                     ri.set_writeconsole_regular(old_writeconsole_regular)
#
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.pyc in __call__(self, *args, **kwargs)
#     176                 v = kwargs.pop(k)
#     177                 kwargs[r_k] = v
# --> 178         return super(SignatureTranslatedFunction, self).__call__(*args, **kwargs)
#     179
#     180 pattern_link = re.compile(r'\\link\{(.+?)\}')
#
# /opt/anaconda/lib/python2.7/site-packages/rpy2/robjects/functions.pyc in __call__(self, *args, **kwargs)
#     104         for k, v in kwargs.items():
#     105             new_kwargs[k] = conversion.py2ri(v)
# --> 106         res = super(Function, self).__call__(*new_args, **new_kwargs)
#     107         res = conversion.ri2ro(res)
#     108         return res
#
# RRuntimeError: Error in eval(expr, envir, enclos) : object 'Temp' not found

# %%
# %%R
# ggsave(filename = "data/figs/EnrichedNumoverTime.jpg", plot = p, width =12, height =6)
