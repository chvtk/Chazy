# %% [markdown]
# ##Import various python functions and modules that we need.

# %%
from pandas import DataFrame
from IPython.display import FileLink

# %% [markdown]
# ##Pylab namespace and inline plots. Import Rmagic.

# %%
# %matplotlib inline
# %load_ext rpy2.ipython
# Out:
# /opt/anaconda/lib/python2.7/site-packages/pytz/__init__.py:29: UserWarning: Module argparse was already imported from /opt/anaconda/lib/python2.7/argparse.pyc, but /opt/anaconda/lib/python2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream

# %% [markdown]
# ##Import R libraries we'll use.

# %%
# %%R
# library(phyloseq)
# library(ggplot2)
# library(foreach)
# library(doParallel)
# library(gridExtra)
# library(vegan)
# library(dplyr)
# library(plyr)
# library(RColorBrewer)
# library(stats)
# library(stringr)

# %% [markdown]
# ##Import data into R. Prune to relevant samples (PS, non-bulk). Get rid of OTUs not observed in at least 25% of samples)

# %%
# %%R
# physeq = import_biom("data/otu_table_SON_wtax.biom", "data/otusn_SON.tree")
# print(physeq)
# sample.data = import_qiime_sample_data("data/Mapping_File_SON.txt")
# physeq = merge_phyloseq(physeq,sample.data)
# physeq.md = sample_data(physeq)
# print(physeq)
# physeq.snorm = transform_sample_counts(physeq, function(x) x/sum(x))
# physeq.thresh = filter_taxa(physeq.snorm, function(x) sum(x > 0) / length(x) > (0.25), TRUE)
# print(physeq.thresh)
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 3027 taxa and 50 samples ]
# tax_table()   Taxonomy Table:    [ 3027 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 3027 tips and 3026 internal nodes ]
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 3027 taxa and 50 samples ]
# sample_data() Sample Data:       [ 50 samples by 7 sample variables ]
# tax_table()   Taxonomy Table:    [ 3027 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 3027 tips and 3026 internal nodes ]
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 1818 taxa and 50 samples ]
# sample_data() Sample Data:       [ 50 samples by 7 sample variables ]
# tax_table()   Taxonomy Table:    [ 1818 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 1818 tips and 1817 internal nodes ]

# %% [markdown]
# ###Calculate Unifrac distances between samples.

# %%
# %%R
# registerDoParallel(cores=20)
# wunif.dist = distance(physeq.thresh,
#                       method = "unifrac",
#                       weighted = TRUE,
#                       fast = TRUE,
#                       parallel = TRUE,
#                       normalized = FALSE)

# %% [markdown]
# ###Adonis Statistics

# %%
# %%R
# physeq.data = as(sample_data(physeq.thresh), "data.frame")
# adonis(wunif.dist ~ Treatment, physeq.data)
# Out:
# Call:
# adonis(formula = wunif.dist ~ Treatment, data = physeq.data)
#
# Terms added sequentially (first to last)
#
#           Df SumsOfSqs  MeanSqs F.Model      R2 Pr(>F)
# Treatment  4   0.15427 0.038566  4.1597 0.26994  0.001 ***
# Residuals 45   0.41721 0.009271         0.73006
# Total     49   0.57148                  1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# %%R
# physeq.data = as(sample_data(physeq.thresh), "data.frame")
# adonis(wunif.dist ~ Month, physeq.data)
# Out:
# Call:
# adonis(formula = wunif.dist ~ Month, data = physeq.data)
#
# Terms added sequentially (first to last)
#
#           Df SumsOfSqs  MeanSqs F.Model      R2 Pr(>F)
# Month      2   0.08736 0.043678  4.2404 0.15286  0.001 ***
# Residuals 47   0.48412 0.010300         0.84714
# Total     49   0.57148                  1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# %%R
# physeq.data = as(sample_data(physeq.thresh), "data.frame")
# adonis(wunif.dist ~ Month + Treatment, physeq.data)
# Out:
# Call:
# adonis(formula = wunif.dist ~ Month + Treatment, data = physeq.data)
#
# Terms added sequentially (first to last)
#
#           Df SumsOfSqs  MeanSqs F.Model      R2 Pr(>F)
# Month      2   0.08736 0.043678  5.6584 0.15286  0.001 ***
# Treatment  4   0.15220 0.038050  4.9293 0.26633  0.001 ***
# Residuals 43   0.33192 0.007719         0.58081
# Total     49   0.57148                  1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# ### Diversity

# %%
# %%R
# div = estimate_richness(physeq, split = TRUE, measures = NULL)

# %%
# %%R
# physeq.md
# Out:
# Sample Data:        [50 samples by 7 sample variables]:
#         Sample_ID Barcode.R Barcode.F Treatment     Month Replicate Till
# S.NTR.2   S.NTR.2  cgagagtt  cgtgagtg       NTR September         2    N
# O.PTH.1   O.PTH.1  actcactg  atcgtacg       PTH   October         1    P
# N.PTH.1   N.PTH.1  ctgcgtag  atcgtacg       PTH  November         1    P
# S.PTH.4   S.PTH.4  gacatagt  ctgcgtgt       PTH September         4    P
# S.NTH.4   S.NTH.4  cgagagtt  ctgcgtgt       NTH September         4    N
# S.NTR.1   S.NTR.1  cgagagtt  tcatcgag       NTR September         1    N
# N.NTH.3   N.NTH.3  tgagtacg  tagcgagt       NTH  November         3    N
# O.PTH.2   O.PTH.2  actcactg  actatctg       PTH   October         2    P
# O.NTR.3   O.NTR.3  acgctact  ggatatct       NTR   October         3    N
# S.NTR.4   S.NTR.4  cgagagtt  gacaccgt       NTR September         4    N
# O.NTH.4   O.NTH.4  acgctact  ctgcgtgt       NTH   October         4    N
# O.NTR.4   O.NTR.4  acgctact  gacaccgt       NTR   October         4    N
# O.PTR.1   O.PTR.1  actcactg  tcatcgag       PTR   October         1    P
# N.PAS       N.PAS  tagtctcc  actatctg       PAS  November        NA <NA>
# N.NTH.4   N.NTH.4  tgagtacg  ctgcgtgt       NTH  November         4    N
# O.PTR.2   O.PTR.2  actcactg  cgtgagtg       PTR   October         2    P
# O.NTH.3   O.NTH.3  acgctact  tagcgagt       NTH   October         3    N
# N.NTR.4   N.NTR.4  tgagtacg  gacaccgt       NTR  November         4    N
# S.PTR.3   S.PTR.3  gacatagt  ggatatct       PTR September         3    P
# N.NTR.3   N.NTR.3  tgagtacg  ggatatct       NTR  November         3    N
# O.NTH.2   O.NTH.2  acgctact  actatctg       NTH   October         2    N
# S.PTH.1   S.PTH.1  gacatagt  atcgtacg       PTH September         1    P
# N.PTH.4   N.PTH.4  ctgcgtag  ctgcgtgt       PTH  November         4    P
# S.NTH.1   S.NTH.1  cgagagtt  atcgtacg       NTH September         1    N
# S.PTR.2   S.PTR.2  gacatagt  cgtgagtg       PTR September         2    P
# O.NTR.1   O.NTR.1  acgctact  tcatcgag       NTR   October         1    N
# N.PTR.1   N.PTR.1  ctgcgtag  tcatcgag       PTR  November         1    P
# S.PTR.1   S.PTR.1  gacatagt  tcatcgag       PTR September         1    P
# N.PTR.2   N.PTR.2  ctgcgtag  cgtgagtg       PTR  November         2    P
# S.NTH.3   S.NTH.3  cgagagtt  tagcgagt       NTH September         3    N
# S.PTH.3   S.PTH.3  gacatagt  tagcgagt       PTH September         3    P
# O.NTH.1   O.NTH.1  acgctact  atcgtacg       NTH   October         1    N
# O.PTR.3   O.PTR.3  actcactg  ggatatct       PTR   October         3    P
# N.NTH.1   N.NTH.1  tgagtacg  atcgtacg       NTH  November         1    N
# N.NTR.1   N.NTR.1  tgagtacg  tcatcgag       NTR  November         1    N
# O.PTH.3   O.PTH.3  actcactg  tagcgagt       PTH   October         3    P
# O.NTR.2   O.NTR.2  acgctact  cgtgagtg       NTR   October         2    N
# S.PTH.2   S.PTH.2  gacatagt  actatctg       PTH September         2    P
# N.PTR.4   N.PTR.4  ctgcgtag  gacaccgt       PTR  November         4    P
# N.NTH.2   N.NTH.2  tgagtacg  actatctg       NTH  November         2    N
# S.PTR.4   S.PTR.4  gacatagt  gacaccgt       PTR September         4    P
# O.PTH.4   O.PTH.4  actcactg  ctgcgtgt       PTH   October         4    P
# N.PTH.3   N.PTH.3  ctgcgtag  tagcgagt       PTH  November         3    P
# S.NTR.3   S.NTR.3  cgagagtt  ggatatct       NTR September         3    N
# N.PTR.3   N.PTR.3  ctgcgtag  ggatatct       PTR  November         3    P
# O.PTR.4   O.PTR.4  actcactg  gacaccgt       PTR   October         4    P
# S.NTH.2   S.NTH.2  cgagagtt  actatctg       NTH September         2    N
# N.PTH.2   N.PTH.2  ctgcgtag  actatctg       PTH  November         2    P
# O.PAS       O.PAS  tagtctcc  atcgtacg       PAS  November        NA <NA>
# N.NTR.2   N.NTR.2  tgagtacg  cgtgagtg       NTR  November         2    N

# %%
# %%R -w 1200 -h 1200
#
# plot_richness(physeq, x = "Treatment", color = "Treatment", shape =("Month"), title = NULL,
#               scales = "free_y", nrow = 3, shsi = NULL, measures = NULL)

# %%
# %%R
# div$soil = physeq.md$Treatment
# div$month = physeq.md$Month
# div$rep = physeq.md$Replicate
# div$till = physeq.md$Till
# head(div)
# Out:
#         Observed    Chao1 se.chao1      ACE   se.ACE  Shannon   Simpson
# S.NTR.2     1347 1749.546 51.64352 1772.484 21.20025 6.017657 0.9932031
# O.PTH.1     1433 1855.086 53.18937 1843.181 21.30411 6.290751 0.9957230
# N.PTH.1     1223 1603.742 50.09166 1617.715 20.17616 6.119910 0.9944901
# S.PTH.4     1313 1868.271 67.73277 1849.059 22.57988 6.236175 0.9954451
# S.NTH.4     1116 1549.769 56.90228 1600.296 21.73004 6.054292 0.9944145
# S.NTR.1     1500 1922.430 52.10796 1941.071 22.12283 6.055726 0.9939101
#         InvSimpson   Fisher soil     month rep till
# S.NTR.2   147.1254 384.4983  NTR September   2    N
# O.PTH.1   233.8113 444.7355  PTH   October   1    P
# N.PTH.1   181.4924 392.9742  PTH  November   1    P
# S.PTH.4   219.5421 438.7192  PTH September   4    P
# S.NTH.4   179.0345 370.3838  NTH September   4    N
# S.NTR.1   164.2076 403.9055  NTR September   1    N

# %%
# %%R
# tbl.mean <- group_by(div,till) %.%
#   summarise(
#           count = n(),
#           mean_Shannon = mean(Shannon),
#           mean_Chao1 = mean(Chao1),
#           stdev_Shannon = sd(Shannon, na.rm=TRUE), #/ sqrt(n())
#           stdev_Chao1 = sd(Chao1, na.rm=TRUE), #/ sqrt(n())
#           stderr_Shannon = sd(Shannon, na.rm=TRUE) / sqrt(count),
#           stderr_Chao1 = sd(Chao1, na.rm=TRUE) / sqrt(count)
#           )

# %%
# %%R
# tbl.mean
# Out:
# Source: local data frame [3 x 8]
#
#   till count mean_Shannon mean_Chao1 stdev_Shannon stdev_Chao1 stderr_Shannon
# 1    N    24     5.968259   1680.755     0.1822585   233.23289     0.03720337
# 2    P    24     6.167831   1785.404     0.1185508   125.63044     0.02419907
# 3   NA     2     5.785449   1247.937     0.1073622    10.47204     0.07591652
# Variables not shown: stderr_Chao1 (dbl)

# %%
# %%R
# head(div)
# Out:
#         Observed    Chao1 se.chao1      ACE   se.ACE  Shannon   Simpson
# S.NTR.2     1347 1749.546 51.64352 1772.484 21.20025 6.017657 0.9932031
# O.PTH.1     1433 1855.086 53.18937 1843.181 21.30411 6.290751 0.9957230
# N.PTH.1     1223 1603.742 50.09166 1617.715 20.17616 6.119910 0.9944901
# S.PTH.4     1313 1868.271 67.73277 1849.059 22.57988 6.236175 0.9954451
# S.NTH.4     1116 1549.769 56.90228 1600.296 21.73004 6.054292 0.9944145
# S.NTR.1     1500 1922.430 52.10796 1941.071 22.12283 6.055726 0.9939101
#         InvSimpson   Fisher soil     month rep till
# S.NTR.2   147.1254 384.4983  NTR September   2    N
# O.PTH.1   233.8113 444.7355  PTH   October   1    P
# N.PTH.1   181.4924 392.9742  PTH  November   1    P
# S.PTH.4   219.5421 438.7192  PTH September   4    P
# S.NTH.4   179.0345 370.3838  NTH September   4    N
# S.NTR.1   164.2076 403.9055  NTR September   1    N

# %%
# %%R
# with(div, pairwise.t.test(Simpson, soil,
#                  p.adjust.method="holm", paired=F))
# Out:
# 	Pairwise comparisons using t tests with pooled SD
#
# data:  Simpson and soil
#
#     NTH  NTR  PAS  PTH
# NTR 1.00 -    -    -
# PAS 1.00 1.00 -    -
# PTH 0.12 0.13 1.00 -
# PTR 0.44 0.44 1.00 1.00
#
# P value adjustment method: holm

# %%
# %%R
# t.test(div$Simpson~div$till)
# Out:
# 	Welch Two Sample t-test
#
# data:  div$Simpson by div$till
# t = -3.2409, df = 30.294, p-value = 0.002893
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.0033435236 -0.0007592121
# sample estimates:
# mean in group N mean in group P
#       0.9927944       0.9948458

# %%
# %%R
# t.test(div$Chao1~div$till)
# Out:
# 	Welch Two Sample t-test
#
# data:  div$Chao1 by div$till
# t = -1.9352, df = 35.31, p-value = 0.061
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -214.39461    5.09584
# sample estimates:
# mean in group N mean in group P
#        1680.755        1785.404

# %%
# %%R
# with(div, pairwise.t.test(Chao1, soil,
#                  p.adjust.method="holm", paired=F))
# Out:
# 	Pairwise comparisons using t tests with pooled SD
#
# data:  Chao1 and soil
#
#     NTH    NTR    PAS    PTH
# NTR 1.0000 -      -      -
# PAS 0.0348 0.0348 -      -
# PTH 0.7957 0.7957 0.0042 -
# PTR 0.9312 0.9312 0.0064 1.0000
#
# P value adjustment method: holm

# %%
 J <- H/log(specnumber(BCI))

# %% [markdown]
# ###Ordinate using weighted unifrac distnaces with NMDS.

# %%
# %%R -w 500 -h 350
# nmds = ordinate(physeq.thresh,
#                 method = "NMDS",
#                 distance = wunif.dist)
# p.nmds = plot_ordination(physeq.thresh, nmds, justDF = TRUE)
# #print(p)
#
# asNumeric = function(x) { as.numeric(as.character(x)) }
#
# p.nmds1 = ggplot(p.nmds, aes(x = NMDS1, y = NMDS2)) +
#         geom_point(aes(color = Treatment, shape = Month), size = 4) +
#         guides(alpha = FALSE, fill=guide_legend(override.aes=list(size=6)))
#
# print(p.nmds1)
# Out:
# Run 0 stress 0.09348751
# Run 1 stress 0.1004722
# Run 2 stress 0.1015289
# Run 3 stress 0.1015309
# Run 4 stress 0.09343614
# ... New best solution
# ... procrustes: rmse 0.00540524  max resid 0.03118037
# Run 5 stress 0.09882892
# Run 6 stress 0.1134359
# Run 7 stress 0.0934872
# ... procrustes: rmse 0.005459298  max resid 0.03155172
# Run 8 stress 0.09614312
# Run 9 stress 0.09616775
# Run 10 stress 0.09772146
# Run 11 stress 0.09352703
# ... procrustes: rmse 0.005148707  max resid 0.03112678
# Run 12 stress 0.0963079
# Run 13 stress 0.09633645
# Run 14 stress 0.0934359
# ... New best solution
# ... procrustes: rmse 0.0007880205  max resid 0.003360525
# *** Solution reached

# %%
# %%R -w 500 -h 350
# pcoa = ordinate(physeq.thresh,
#                 method = "PCoA",
#                 distance = wunif.dist)
# p.pcoa = plot_ordination(physeq.thresh, pcoa, justDF = TRUE)
# #print(p)
#
# asNumeric = function(x) { as.numeric(as.character(x)) }
#
# p.pcoa1 = ggplot(p.pcoa, aes(x = Axis.1, y = Axis.2)) +
#         geom_point(aes(color = Treatment, shape = Month), size = 4) +
#         guides(alpha = FALSE, fill=guide_legend(override.aes=list(size=6)))
#
# print(p.pcoa1)

# %%
# %%R -w 1000 -h 350
# pdf("figs/full_ordination_Chazy_SON.pdf", width = 6, height = 5)
# grid.arrange(p.nmds1, ncol= 1)
# dev.off()
# Out:
# png
#   2

# %%
FileLink("figs/full_ordination_Chazy_SON.pdf")
# Out:
# /home/chantal/Chazy/figs/full_ordination_Chazy.pdf

# %% [markdown]
# # Checking different distance matrices

# %%
# %%R
# dist_methods = unlist(distance("list"))
# dist_methods = dist_methods[-(1:2)]
# dist_methods = dist_methods[-which(dist_methods == "ANY")]
# dist_methods = dist_methods[-which(dist_methods == "morisita")]
# dist_methods = dist_methods[-which(dist_methods == "mountford")]
# dist_methods = c(dist_methods, c=c("wunif","uwunif"))
# print(dist_methods)
# Out:
#        DPCoA          JSD     vegdist1     vegdist2     vegdist3     vegdist4
#      "dpcoa"        "jsd"  "manhattan"  "euclidean"   "canberra"       "bray"
#     vegdist5     vegdist6     vegdist7     vegdist8    vegdist10    vegdist12
# "kulczynski"    "jaccard"      "gower"   "altGower"       "horn"       "raup"
#    vegdist13    vegdist14    vegdist15   betadiver1   betadiver2   betadiver3
#   "binomial"       "chao"        "cao"          "w"         "-1"          "c"
#   betadiver4   betadiver5   betadiver6   betadiver7   betadiver8   betadiver9
#         "wb"          "r"          "I"          "e"          "t"         "me"
#  betadiver10  betadiver11  betadiver12  betadiver13  betadiver14  betadiver15
#          "j"        "sor"          "m"         "-2"         "co"         "cc"
#  betadiver16  betadiver17  betadiver18  betadiver19  betadiver20  betadiver21
#          "g"         "-3"          "l"         "19"         "hk"        "rlb"
#  betadiver22  betadiver23  betadiver24        dist1        dist2        dist3
#        "sim"         "gl"          "z"    "maximum"     "binary"  "minkowski"
#           c1           c2
#      "wunif"     "uwunif"

# %%
# %%R
# dlist.nmds = vector("list", length(dist_methods))
# dlist.mds = vector("list", length(dist_methods))
# names(dlist.nmds) = dist_methods
# names(dlist.mds) = dist_methods
# t = physeq.thresh
# for (i in dist_methods) {
#     # Calculate distance matrix
#     if ( i == "wunif" ) {
#             registerDoParallel(cores=30)
#             iDist <- UniFrac(t,
#                              weighted = TRUE,
#                              fast = TRUE,
#                              normalized = FALSE,
#                              parallel = TRUE)
#         } else if ( i == "uwunif" ) {
#             registerDoParallel(cores=30)
#             iDist <- UniFrac(t,
#                              weighted = FALSE,
#                              fast = TRUE,
#                              normalized = FALSE,
#                              parallel = TRUE)
#         } else
#             iDist <- distance(t, method = i)
#
#     # Calculate ordination
#     iNMDS <- ordinate(t, "NMDS", distance = iDist)
#     iMDS <- ordinate(t, "MDS", distance = iDist)
#
#     df.nmds <- NULL
#     df.mds <- NULL
#     df.nmds <- plot_ordination(t, iNMDS, justDF = TRUE)
#     df.mds <- plot_ordination(t, iMDS, justDF = TRUE)
#     dlist.nmds[[i]] = df.nmds
#     dlist.mds[[i]] = df.mds
# }
# Out:
# Run 0 stress 0.06933658
# Run 1 stress 0.06963774
# ... procrustes: rmse 0.003717154  max resid 0.01808164
# Run 2 stress 0.07292109
# Run 3 stress 0.07650397
# Run 4 stress 0.07638267
# Run 5 stress 0.08433503
# Run 6 stress 0.06933306
# ... New best solution
# ... procrustes: rmse 0.001183985  max resid 0.00570549
# *** Solution reached
#
# Run 0 stress 0.1373399
# Run 1 stress 0.1402371
# Run 2 stress 0.1373403
# ... procrustes: rmse 8.190485e-05  max resid 0.0003309276
# *** Solution reached
#
# Run 0 stress 0.137466
# Run 1 stress 0.1374495
# ... New best solution
# ... procrustes: rmse 0.01405926  max resid 0.07489693
# Run 2 stress 0.1374494
# ... New best solution
# ... procrustes: rmse 6.191434e-05  max resid 0.0002609282
# *** Solution reached
#
# Run 0 stress 0.1285063
# Run 1 stress 0.1387776
# Run 2 stress 0.1287826
# ... procrustes: rmse 0.05485054  max resid 0.3522245
# Run 3 stress 0.1309867
# Run 4 stress 0.1308419
# Run 5 stress 0.1285007
# ... New best solution
# ... procrustes: rmse 0.0008544411  max resid 0.005537158
# *** Solution reached
#
# Run 0 stress 0.09727059
# Run 1 stress 0.101023
# Run 2 stress 0.09727231
# ... procrustes: rmse 0.002674289  max resid 0.009779066
# *** Solution reached
#
# Run 0 stress 0.1332268
# Run 1 stress 0.1341525
# Run 2 stress 0.1341481
# Run 3 stress 0.1863255
# Run 4 stress 0.1341521
# Run 5 stress 0.1541749
# Run 6 stress 0.1332471
# ... procrustes: rmse 0.002517587  max resid 0.01555246
# Run 7 stress 0.134148
# Run 8 stress 0.1738892
# Run 9 stress 0.1534207
# Run 10 stress 0.1341527
# Run 11 stress 0.1540265
# Run 12 stress 0.1541742
# Run 13 stress 0.1343498
# Run 14 stress 0.133227
# ... procrustes: rmse 0.00027865  max resid 0.00147257
# *** Solution reached
#
# Run 0 stress 0.1334345
# Run 1 stress 0.1530933
# Run 2 stress 0.1660754
# Run 3 stress 0.1346195
# Run 4 stress 0.1346186
# Run 5 stress 0.1346208
# Run 6 stress 0.1346183
# Run 7 stress 0.1344628
# Run 8 stress 0.1346193
# Run 9 stress 0.1544672
# Run 10 stress 0.1334345
# ... New best solution
# ... procrustes: rmse 2.729669e-05  max resid 0.0001538992
# *** Solution reached
#
# Run 0 stress 0.1332398
# Run 1 stress 0.1332468
# ... procrustes: rmse 0.001377372  max resid 0.008680397
# *** Solution reached
#
# Run 0 stress 0.1663603
# Run 1 stress 0.212591
# Run 2 stress 0.1663602
# ... New best solution
# ... procrustes: rmse 0.0001775339  max resid 0.0009490375
# *** Solution reached
#
# Run 0 stress 0.1680351
# Run 1 stress 0.1716518
# Run 2 stress 0.1694193
# Run 3 stress 0.1673239
# ... New best solution
# ... procrustes: rmse 0.07932355  max resid 0.379742
# Run 4 stress 0.2063554
# Run 5 stress 0.1694043
# Run 6 stress 0.171652
# Run 7 stress 0.1716537
# Run 8 stress 0.2026915
# Run 9 stress 0.1716518
# Run 10 stress 0.1673244
# ... procrustes: rmse 0.0001766896  max resid 0.0008084899
# *** Solution reached
#
# Run 0 stress 0.1217225
# Run 1 stress 0.1226103
# Run 2 stress 0.1303152
# Run 3 stress 0.1217222
# ... New best solution
# ... procrustes: rmse 0.0002077453  max resid 0.00084528
# *** Solution reached
#
# Run 0 stress 6.901266e-17
# Run 1 stress 9.740046e-05
# ... procrustes: rmse 0.1306583  max resid 0.5292459
# Run 2 stress 0.0002297583
# ... procrustes: rmse 0.1291971  max resid 0.5300011
# Run 3 stress 9.359178e-05
# ... procrustes: rmse 0.1260513  max resid 0.4984048
# Run 4 stress 0.0001058373
# ... procrustes: rmse 0.1297529  max resid 0.5135856
# Run 5 stress 8.498543e-05
# ... procrustes: rmse 0.1327554  max resid 0.5615315
# Run 6 stress 9.071961e-05
# ... procrustes: rmse 0.1310949  max resid 0.5385687
# Run 7 stress 4.378202e-05
# ... procrustes: rmse 0.1273031  max resid 0.4955568
# Run 8 stress 8.263976e-05
# ... procrustes: rmse 0.130861  max resid 0.536517
# Run 9 stress 0
# ... New best solution
# ... procrustes: rmse 0.1237431  max resid 0.4718345
# Run 10 stress 9.824276e-05
# ... procrustes: rmse 0.1383637  max resid 0.2677695
# Run 11 stress 6.400817e-05
# ... procrustes: rmse 0.1386049  max resid 0.2573105
# Run 12 stress 9.612614e-05
# ... procrustes: rmse 0.1386567  max resid 0.2556925
# Run 13 stress 3.037239e-05
# ... procrustes: rmse 0.1375253  max resid 0.2436767
# Run 14 stress 7.755586e-05
# ... procrustes: rmse 0.1333853  max resid 0.2262251
# Run 15 stress 8.396564e-05
# ... procrustes: rmse 0.1376485  max resid 0.2438496
# Run 16 stress 6.22385e-05
# ... procrustes: rmse 0.1365555  max resid 0.2930379
# Run 17 stress 9.381125e-05
# ... procrustes: rmse 0.1360464  max resid 0.2377218
# Run 18 stress 8.139329e-05
# ... procrustes: rmse 0.1346011  max resid 0.244099
# Run 19 stress 8.214307e-05
# ... procrustes: rmse 0.1394448  max resid 0.2843776
# Run 20 stress 8.473292e-05
# ... procrustes: rmse 0.1398185  max resid 0.3053073
# Error in array(STATS, dims[perm]) : 'dims' cannot be of length 0
# In addition: Warning message:
# In metaMDS(ps.dist) :
#   Stress is (nearly) zero - you may have insufficient data
# Error in array(STATS, dims[perm]) : 'dims' cannot be of length 0

# %%
# %%R -h 1800 -w 2000
# df.nmds.all = ldply(dlist.nmds, function(x) x)
# names(df.nmds.all)[1] <- "distance"
# p = ggplot(df.nmds.all, aes(NMDS1, NMDS2, color = Treatment))
# #p = p + scale_area(range = c(1,5))
# p = p + geom_point(alpha = 0.5, size = 6)
# p = p + facet_wrap(~distance, scales = "free")
# p = p + ggtitle("NMDS on various distance metrics for C-SIP dataset")
# print(p)

# %%
FileLink("figs/dragonfly_inset_facet_grid.pdf")
# Out:
# /home/chantal/RNASIP/figs/dragonfly_inset_facet_grid.pdf

# %%
# %%R
# site.scores = p.nmds[,c(1,2)]
# dummy.treatment = model.matrix( ~ Treatment - 1, data = p.nmds)[,2]
# e = envfit(site.scores, dummy.treatment)
# #x.component = e$vectors$arrows[1,"Axis.1"]
# #y.component = e$vectors$arrows[1,"Axis.2"]

# %%
# %%R
# print(head(e))
# Out:
# $vectors
#         NMDS1    NMDS2     r2 Pr(>r)
# [1,] -0.54438  0.83884 0.3775  0.001 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# P values based on 999 permutations.
#
# $factors
# NULL
#
# $na.action
# function (object, ...)
# UseMethod("na.action")
# <bytecode: 0x4db54e8>
# <environment: namespace:stats>

# %%
# %%R
# if( setequal(row.names(p.nmds), row.names(t(otu_table(physeq.thresh)))) ){
#     w = wascores(p.nmds[,c(1,2)],t(otu_table(physeq.thresh)),expand=TRUE)
# } else {
#     print("Indices don't match")
#     print(setdiff(row.names(m), row.names(t(otu_table(physeq.thresh)))))
# }
# otu.scores = data.frame(w)

# %%
# %%R
# supp = tax_table(physeq.thresh)
# if( setequal(row.names(otu.scores), row.names(supp)) ){
#     otu.scores.wtax = data.frame(otu.scores, supp)
# } else {
#     print("Indices not the same.")
#     print(setdiff(row.names(w.df), row.names(supp)))
# }

# %%
# %%R -w 1400 -h 600
# p.sites = ggplot(p.nmds, aes(x = NMDS1, y = NMDS2))
# p.sites = p.sites + geom_point(aes(fill = Treatment), pch = 21, alpha = 0.75, size = 6)
# #p.sites = p.sites + scale_area(range = c(0,4))
# p.sites = p.sites + ylim(c(-0.11, 0.25)) + xlim(c(-0.25, 0.6125))
# #p.sites = p.sites + geom_segment(aes(x = 0, y = 0))#,
#                                      #xend = x.component/5,
#                                      #yend = y.component/5),
#                                  #arrow = arrow())
#
# p.otus = ggplot(otu.scores.wtax, aes(x = NMDS1, y = NMDS2))
# p.otus = p.otus + geom_point(aes(fill = Rank2), pch=21, alpha = 0.5, size = 4)
# p.otus = p.otus + labs(shape = "OTU", fill = "Phylum")
# p.otus = p.otus + ylim(c(-0.11, 0.25)) + xlim(c(-0.25, 0.6125))
#
# p.biplot = grid.arrange(p.sites, p.otus, ncol = 2)
# print(p.biplot)
# Out:
# NULL

# %%
# %%R
# otu.scores.sorted <- otu.scores.wtax[order(otu.scores.wtax$NMDS2, decreasing = TRUE), ]
# print(otu.scores.sorted[1:20,1:5])
# Out:
#                NMDS1     NMDS2    Rank1             Rank2
# OTU.2775  0.35994121 0.3080254 Bacteria  __Planctomycetes
# OTU.264   0.31134200 0.2995292 Bacteria  __Proteobacteria
# OTU.518   0.35499342 0.2942920 Bacteria  __Proteobacteria
# OTU.1252  0.24965584 0.2548632 Bacteria  __Actinobacteria
# OTU.1211  0.13612992 0.2336888 Bacteria  __Actinobacteria
# OTU.456   0.20967757 0.2275943 Bacteria   __Bacteroidetes
# OTU.153   0.20026809 0.2129773 Bacteria  __Proteobacteria
# OTU.392   0.19083886 0.2097227 Bacteria  __Proteobacteria
# OTU.369   0.02149474 0.2046898 Bacteria  __Proteobacteria
# OTU.500  -0.04694715 0.1882972 Bacteria   __Acidobacteria
# OTU.3086  0.47069587 0.1850507 Bacteria   __Bacteroidetes
# OTU.872   0.16072406 0.1840854 Bacteria   __Acidobacteria
# OTU.1765  0.05974535 0.1837154 Bacteria  __Actinobacteria
# OTU.997   0.08569947 0.1811379 Bacteria  __Planctomycetes
# OTU.379   0.14326127 0.1806574 Bacteria  __Proteobacteria
# OTU.1443  0.19404371 0.1778753 Bacteria    __Spirochaetes
# OTU.1864  0.29127493 0.1740401 Bacteria __Verrucomicrobia
# OTU.517   0.21427770 0.1719383 Bacteria  __Proteobacteria
# OTU.1830  0.27943269 0.1702922 Bacteria __Verrucomicrobia
# OTU.730   0.12621042 0.1686861 Bacteria  __Planctomycetes
#                           Rank3
# OTU.2775     __Planctomycetacia
# OTU.264   __Gammaproteobacteria
# OTU.518   __Alphaproteobacteria
# OTU.1252      __Thermoleophilia
# OTU.1211      __Thermoleophilia
# OTU.456      __Sphingobacteriia
# OTU.153   __Gammaproteobacteria
# OTU.392   __Alphaproteobacteria
# OTU.369   __Gammaproteobacteria
# OTU.500      __Acidobacteriales
# OTU.3086     __Sphingobacteriia
# OTU.872  __Order_Incertae_Sedis
# OTU.1765      __Thermoleophilia
# OTU.997      __Planctomycetacia
# OTU.379   __Alphaproteobacteria
# OTU.1443       __Spirochaetales
# OTU.1864     __OPB35_soil_group
# OTU.517   __Alphaproteobacteria
# OTU.1830     __OPB35_soil_group
# OTU.730      __Planctomycetacia

# %%
# %%R -w 1200 -h 800
#
# p.otus = ggplot(otu.scores.wtax, aes(x = NMDS1, y = NMDS2))
# p.otus = p.otus + geom_point(aes(fill = Rank2), pch=21, size=2, alpha=0.5)
# p.otus = p.otus + facet_wrap(~Rank2)
#
# print(p.otus)
