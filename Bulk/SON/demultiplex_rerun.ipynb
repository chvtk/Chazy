# %%
import screed
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
from mpltools import style
import mpld3
#from mpld3 import plugins
#import jinja2
#from mpld3._objects import D3Line2D, D3Collection
#mpld3.disable_notebook()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-21-1df04d5f044c> in <module>()
#       4 import matplotlib.pyplot as plt
#       5 import numpy as np
# ----> 6 from mpltools import style
#       7 import mpld3
#       8 #from mpld3 import plugins
#
# ImportError: No module named mpltools

# %%
style.use("ggplot")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-647a92768351> in <module>()
# ----> 1 style.use("ggplot")
#
# NameError: name 'style' is not defined

# %%
# %matplotlib inline

# %%
ir1 = "/var/seq_data/rawseqs_Dec2014/Rerun/Rerun_indexRead1.fastq"
ir2 = "/var/seq_data/rawseqs_Dec2014/Rerun/Rerun_indexRead2.fastq"

# %%
screed.read_fastq_sequences(ir1)
screed.read_fastq_sequences(ir2)

# %%
ir1db = screed.ScreedDB(ir1)
ir2db = screed.ScreedDB(ir2)

# %%
df_map = pd.read_csv("data/Mapping_File_SON.csv", delimiter=",", usecols=[0,1,2], names=["SampleID","i1","i2"])
df_map
# Out:
#       SampleID         i1         i2
# 0   Sample_ID   Barcode.R  Barcode.F
# 1      S.NTH.1   cgagagtt   atcgtacg
# 2      S.NTH.2   cgagagtt   actatctg
# 3      S.NTH.3   cgagagtt   tagcgagt
# 4      S.NTH.4   cgagagtt   ctgcgtgt
# 5      S.NTR.1   cgagagtt   tcatcgag
# 6      S.NTR.2   cgagagtt   cgtgagtg
# 7      S.NTR.3   cgagagtt   ggatatct
# 8      S.NTR.4   cgagagtt   gacaccgt
# 9      S.PTH.1   gacatagt   atcgtacg
# 10     S.PTH.2   gacatagt   actatctg
# 11     S.PTH.3   gacatagt   tagcgagt
# 12     S.PTH.4   gacatagt   ctgcgtgt
# 13     S.PTR.1   gacatagt   tcatcgag
# 14     S.PTR.2   gacatagt   cgtgagtg
# 15     S.PTR.3   gacatagt   ggatatct
# 16     S.PTR.4   gacatagt   gacaccgt
# 17     O.NTH.1   acgctact   atcgtacg
# 18     O.NTH.2   acgctact   actatctg
# 19     O.NTH.3   acgctact   tagcgagt
# 20     O.NTH.4   acgctact   ctgcgtgt
# 21     O.NTR.1   acgctact   tcatcgag
# 22     O.NTR.2   acgctact   cgtgagtg
# 23     O.NTR.3   acgctact   ggatatct
# 24     O.NTR.4   acgctact   gacaccgt
# 25     O.PTH.1   actcactg   atcgtacg
# 26     O.PTH.2   actcactg   actatctg
# 27     O.PTH.3   actcactg   tagcgagt
# 28     O.PTH.4   actcactg   ctgcgtgt
# 29     O.PTR.1   actcactg   tcatcgag
# 30     O.PTR.2   actcactg   cgtgagtg
# 31     O.PTR.3   actcactg   ggatatct
# 32     O.PTR.4   actcactg   gacaccgt
# 33     N.NTH.1   tgagtacg   atcgtacg
# 34     N.NTH.2   tgagtacg   actatctg
# 35     N.NTH.3   tgagtacg   tagcgagt
# 36     N.NTH.4   tgagtacg   ctgcgtgt
# 37     N.NTR.1   tgagtacg   tcatcgag
# 38     N.NTR.2   tgagtacg   cgtgagtg
# 39     N.NTR.3   tgagtacg   ggatatct
# 40     N.NTR.4   tgagtacg   gacaccgt
# 41     N.PTH.1   ctgcgtag   atcgtacg
# 42     N.PTH.2   ctgcgtag   actatctg
# 43     N.PTH.3   ctgcgtag   tagcgagt
# 44     N.PTH.4   ctgcgtag   ctgcgtgt
# 45     N.PTR.1   ctgcgtag   tcatcgag
# 46     N.PTR.2   ctgcgtag   cgtgagtg
# 47     N.PTR.3   ctgcgtag   ggatatct
# 48     N.PTR.4   ctgcgtag   gacaccgt
# 49       O.PAS   tagtctcc   atcgtacg
# 50       N.PAS   tagtctcc   actatctg

# %%
map_d = dict(map(lambda x: (x[0] + x[1], x[2]), zip(df_map.i1, df_map.i2, df_map.SampleID)))
print map_d.keys()[10], map_d[map_d.keys()[10]]
# Out:
# ctgcgtagctgcgtgt N.PTH.4

# %%
print map_d
# Out:
# {'tgagtacgactatctg': 'N.NTH.2', 'actcactggacaccgt': 'O.PTR.4', 'cgagagttactatctg': 'S.NTH.2', 'tagtctccatcgtacg': 'O.PAS', 'ctgcgtagcgtgagtg': 'N.PTR.2', 'acgctactgacaccgt': 'O.NTR.4', 'tgagtacggacaccgt': 'N.NTR.4', 'cgagagttctgcgtgt': 'S.NTH.4', 'tgagtacgatcgtacg': 'N.NTH.1', 'ctgcgtagtagcgagt': 'N.PTH.3', 'ctgcgtagctgcgtgt': 'N.PTH.4', 'gacatagttagcgagt': 'S.PTH.3', 'tgagtacgggatatct': 'N.NTR.3', 'actcactgggatatct': 'O.PTR.3', 'ctgcgtagtcatcgag': 'N.PTR.1', 'cgagagttgacaccgt': 'S.NTR.4', 'gacatagttcatcgag': 'S.PTR.1', 'acgctacttcatcgag': 'O.NTR.1', 'acgctactctgcgtgt': 'O.NTH.4', 'ctgcgtagactatctg': 'N.PTH.2', 'cgagagtttagcgagt': 'S.NTH.3', 'cgagagttatcgtacg': 'S.NTH.1', 'gacatagtctgcgtgt': 'S.PTH.4', 'ctgcgtagggatatct': 'N.PTR.3', 'gacatagtcgtgagtg': 'S.PTR.2', 'gacatagtactatctg': 'S.PTH.2', 'cgagagttcgtgagtg': 'S.NTR.2', 'actcactgctgcgtgt': 'O.PTH.4', 'tagtctccactatctg': 'N.PAS', 'gacatagtgacaccgt': 'S.PTR.4', 'cgagagtttcatcgag': 'S.NTR.1', 'ctgcgtaggacaccgt': 'N.PTR.4', 'gacatagtatcgtacg': 'S.PTH.1', 'actcactgcgtgagtg': 'O.PTR.2', 'ctgcgtagatcgtacg': 'N.PTH.1', 'tgagtacgtagcgagt': 'N.NTH.3', 'acgctactatcgtacg': 'O.NTH.1', 'actcactgtagcgagt': 'O.PTH.3', 'gacatagtggatatct': 'S.PTR.3', 'Barcode.RBarcode.F': 'Sample_ID ', 'acgctacttagcgagt': 'O.NTH.3', 'acgctactggatatct': 'O.NTR.3', 'actcactgtcatcgag': 'O.PTR.1', 'tgagtacgtcatcgag': 'N.NTR.1', 'actcactgatcgtacg': 'O.PTH.1', 'cgagagttggatatct': 'S.NTR.3', 'acgctactactatctg': 'O.NTH.2', 'acgctactcgtgagtg': 'O.NTR.2', 'tgagtacgctgcgtgt': 'N.NTH.4', 'actcactgactatctg': 'O.PTH.2', 'tgagtacgcgtgagtg': 'N.NTR.2'}

# %%
screed.read_fastq_sequences("/var/seq_data/rawseqs_Dec2014/Rerun/pear_merged_raw-2015-02-16.assembled.fastq")
# Out:
# <ScreedDB, '/var/seq_data/rawseqs_Dec2014/pear_merged_raw-2015-01-12.assembled.fastq_screed'>

# %%
db = screed.ScreedDB("/var/seq_data/rawseqs_Dec2014/Rerun/pear_merged_raw-2015-02-16.assembled.fastq_screed")

# %%
counter = 0
unassigned = 0
cnt = Counter()
fn = "/var/seq_data/Chazy/rerun_Chantal_SON.assembled.dmult.fastq"
with open(fn, "w") as out:
    for rec in db.itervalues():
        index_concat = ir1db[rec["name"]]["sequence"] + ir2db[rec["name"]]["sequence"]
        try:
            new_name = map_d[index_concat.lower()] + "_" + str(counter) #case sensitive
        except KeyError:
            unassigned += 1
            continue
        counter += 1
        cnt[map_d[index_concat.lower()]] += 1 #case sensitive
        s, q = rec["sequence"], rec["accuracy"]
        out.write("@%s orig_name=%s\n%s\n+\n%s\n"%(new_name,rec["name"],s,q))
print "Unable to assign %s reads to samples"%unassigned
# Out:
# Unable to assign 6806115 reads to samples

# %%
X = np.arange(len(cnt.keys()))
Y = [v for k, v in cnt.most_common()]
fig = plt.figure()
fig.set_size_inches((18,8))
ax = fig.add_subplot(111)
bars = ax.bar(X, Y, width=0.50)
xlims = ax.set_xlim((X.min(), X.max()))
xt = ax.set_xticks(X)
xtl = ax.set_xticklabels([k for k, v in cnt.most_common()], rotation=90, ha="center", size=6)
