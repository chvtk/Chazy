# %%
import screed
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
from mpltools import style
import mpld3
#from mpld3 import plugins
#import jinja2
#from mpld3._objects import D3Line2D, D3Collection
#mpld3.disable_notebook()
# Out:
# /opt/anaconda/lib/python2.7/site-packages/mpltools/style/__init__.py:42: FutureWarning:
#
#     The style-sheet functionality in mpltools has been integrated into
#     Matplotlib >= 1.4. This module will be removed in a future release.
#
#     Note that style-sheets used by `matplotlib.style` use the standard
#     Matplotlib rc-file syntax instead of the INI format used by `mpltools`.
#     This mostly means un-quoting strings and changing '=' to ':'.
#
#
#   """, FutureWarning)

# %%
style.use("ggplot")

# %%
# %matplotlib inline

# %%
ir1 = "/var/seq_data/Chazy/515_806_SIP/Pool1/Index1.fastq.gz"
ir2 = "/var/seq_data/Chazy/515_806_SIP/Pool1/Index2.fastq.gz"

# %%
screed.read_fastq_sequences(ir1)
screed.read_fastq_sequences(ir2)
# Out:
# <ScreedDB, '/var/seq_data/Chazy/515_806_SIP/Pool1/Index2.fastq.gz_screed'>

# %%
ir1db = screed.ScreedDB(ir1)
ir2db = screed.ScreedDB(ir2)

# %%
df_map = pd.read_csv("data/Metadata_ChazySIP_pool1_515806.txt", delimiter="\t", usecols=[1,6,7], names=["SampleID","i1","i2"])
df_map
# Out:
#                   SampleID         i1         i2
# 0              Full.sample  Rev.index  Fwd.index
# 1     12C.PTH.D30.R4.Frac6   cgagagtt   atcgtacg
# 2     12C.PTH.D30.R4.Frac7   cgagagtt   actatctg
# 3     12C.PTH.D30.R4.Frac8   cgagagtt   tagcgagt
# 4     12C.PTH.D30.R4.Frac9   cgagagtt   ctgcgtgt
# 5    12C.PTH.D30.R4.Frac10   cgagagtt   tcatcgag
# 6    12C.PTH.D30.R4.Frac11   cgagagtt   cgtgagtg
# 7    12C.PTH.D30.R4.Frac12   cgagagtt   ggatatct
# 8    12C.PTH.D30.R4.Frac13   cgagagtt   gacaccgt
# 9    12C.PTH.D30.R4.Frac14   gacatagt   atcgtacg
# 10   12C.PTH.D30.R4.Frac15   gacatagt   actatctg
# 11   12C.PTH.D30.R4.Frac16   gacatagt   tagcgagt
# 12   12C.PTH.D30.R4.Frac17   gacatagt   ctgcgtgt
# 13   12C.PTH.D30.R4.Frac18   gacatagt   tcatcgag
# 14   12C.PTH.D30.R4.Frac19   gacatagt   cgtgagtg
# 15   12C.PTH.D30.R4.Frac20   gacatagt   ggatatct
# 16   12C.PTH.D30.R4.Frac21   gacatagt   gacaccgt
# 17   12C.PTH.D30.R4.Frac22   acgctact   atcgtacg
# 18   12C.PTH.D30.R4.Frac23   acgctact   actatctg
# 19   12C.PTH.D30.R4.Frac24   acgctact   tagcgagt
# 20   12C.PTH.D30.R4.Frac25   acgctact   ctgcgtgt
# 21   12C.PTH.D30.R4.Frac26   acgctact   tcatcgag
# 22   12C.PTH.D30.R4.Frac27   acgctact   cgtgagtg
# 23   12C.PTH.D30.R4.Frac28   acgctact   ggatatct
# 24      12C.PTH.D30.R4.H2O   acgctact   gacaccgt
# 25     13X.NTH.D3.R4.Frac5   actcactg   atcgtacg
# 26     13X.NTH.D3.R4.Frac6   actcactg   actatctg
# 27     13X.NTH.D3.R4.Frac7   actcactg   tagcgagt
# 28     13X.NTH.D3.R4.Frac8   actcactg   ctgcgtgt
# 29     13X.NTH.D3.R4.Frac9   actcactg   tcatcgag
# ..                     ...        ...        ...
# 163   12C.NTH.D3.R4.Frac17   actacgac   agagtcac
# 164   12C.NTH.D3.R4.Frac18   actacgac   tacgagac
# 165   12C.NTH.D3.R4.Frac19   actacgac   acgtctcg
# 166   12C.NTH.D3.R4.Frac20   actacgac   tcgacgag
# 167   12C.NTH.D3.R4.Frac21   actacgac   gatcgtgt
# 168   12C.NTH.D3.R4.Frac22   actacgac   gtcagata
# 169   12C.NTH.D3.R4.Frac23   gtctgcta   ctactata
# 170   12C.NTH.D3.R4.Frac24   gtctgcta   cgttacta
# 171   12C.NTH.D3.R4.Frac25   gtctgcta   agagtcac
# 172   12C.NTH.D3.R4.Frac26   gtctgcta   tacgagac
# 173   12C.NTH.D3.R4.Frac27   gtctgcta   acgtctcg
# 174   12C.NTH.D3.R4.Frac28   gtctgcta   tcgacgag
# 175      12C.NTH.D3.R4.H2O   gtctgcta   gatcgtgt
# 176    12C.PTH.D3.R4.Frac5   gtctgcta   gtcagata
# 177    12C.PTH.D3.R4.Frac6   gtctatga   ctactata
# 178    12C.PTH.D3.R4.Frac7   gtctatga   cgttacta
# 179    12C.PTH.D3.R4.Frac8   gtctatga   agagtcac
# 180    12C.PTH.D3.R4.Frac9   gtctatga   tacgagac
# 181   12C.PTH.D3.R4.Frac10   gtctatga   acgtctcg
# 182   12C.PTH.D3.R4.Frac11   gtctatga   tcgacgag
# 183   12C.PTH.D3.R4.Frac12   gtctatga   gatcgtgt
# 184   12C.PTH.D3.R4.Frac13   gtctatga   gtcagata
# 185   12C.PTH.D3.R4.Frac14   tatagcga   ctactata
# 186   12C.PTH.D3.R4.Frac15   tatagcga   cgttacta
# 187   12C.PTH.D3.R4.Frac16   tatagcga   agagtcac
# 188   12C.PTH.D3.R4.Frac17   tatagcga   tacgagac
# 189   12C.PTH.D3.R4.Frac18   tatagcga   acgtctcg
# 190   12C.PTH.D3.R4.Frac19   tatagcga   tcgacgag
# 191   12C.PTH.D3.R4.Frac20   tatagcga   gatcgtgt
# 192   12C.PTH.D3.R4.Frac21   tatagcga   gtcagata
#
# [193 rows x 3 columns]

# %%
map_d = dict(map(lambda x: (x[0] + x[1], x[2]), zip(df_map.i1, df_map.i2, df_map.SampleID)))
print map_d.keys()[10], map_d[map_d.keys()[10]]
# Out:
# tatagcgatcatcgag 13X.PTH.D7.R4.Frac22

# %%
print map_d
# Out:
# {'tgagtacgactatctg': '13X.NTH.D3.R4.Frac14', 'tatagcgagacaccgt': '13X.PTH.D7.R4.Frac25', 'tatagcgatacgagac': '12C.PTH.D3.R4.Frac17', 'actacgacgatcgtgt': '12C.NTH.D3.R4.Frac21', 'gtctatgactgcgtgt': '13X.PTH.D7.R4.Frac13', 'tagtctccggatatct': '13C.NTH.D14.R4.Frac9', 'tatagcgaactatctg': '13X.PTH.D7.R4.Frac19', 'actcactgggatatct': '13X.NTH.D3.R4.Frac11', 'tagtctcctacgagac': '12C.PTH.D1.R4.Frac27', 'cgagcgactcgacgag': '12C.NTH.D3.R4.Frac12', 'tatagcgatcatcgag': '13X.PTH.D7.R4.Frac22', 'tagtctccatcgtacg': '13X.NTH.D3.R4.Frac29', 'cgagcgacacgtctcg': '12C.NTH.D3.R4.Frac11',
gtgt': '13C.NTH.D14.R4.Frac14', 'gtctatgatacgagac': '12C.PTH.D3.R4.Frac9', 'gacatagtgtcagata': '13C.PTH.D14.R4.Frac16', 'actacgacgtcagata': '12C.NTH.D3.R4.Frac22', 'cgagcgacgacaccgt': '13C.NTH.D14.R4.Frac18', 'tatagcgatcgacgag': '12C.PTH.D3.R4.Frac19', 'actcactggtcagata': '12C.PTH.D1.R4.Frac7', 'gacatagtgatcgtgt': '13C.PTH.D14.R4.Frac15', 'gtctgctactgcgtgt': '13X.PTH.D7.R4.Frac5', 'cgagcgactacgagac': '12C.NTH.D3.R4.Frac10', 'gtctgctaagagtcac': '12C.NTH.D3.R4.Frac25', 'gtctatgatagcgagt': '13X.PTH.D7.R4.Frac12', 'gacatagtggatatct': '12C.PTH.D30.R4.Frac20', 'gtctgctaggatatct': '13X.PTH.D7.R4.Frac8', 'actacgacatcgtacg': '13C.NTH.D14.R4.Frac19', 'acgctacttagcgagt': '12C.PTH.D30.R4.Frac24', 'actcactgtcgacgag': '12C.PTH.D1.R4.Frac5', 'acgctactctactata': '13C.PTH.D14.R4.Frac17', 'tatagcgatagcgagt': '13X.PTH.D7.R4.Frac20', 'tatagcgaggatatct': '13X.PTH.D7.R4.Frac24', 'gtctgctaactatctg': '13C.NTH.D14.R4.Frac28', 'acgctactactatctg': '12C.PTH.D30.R4.Frac23', 'actacgacggatatct': '13C.NTH.D14.R4.Frac25', 'acgctactcgtgagtg': '12C.PTH.D30.R4.Frac27', 'cgagagttgtcagata': '13C.PTH.D14.R4.Frac8', 'tgagtacgctgcgtgt': '13X.NTH.D3.R4.Frac16', 'actcactgactatctg': '13X.NTH.D3 ...

# %%
screed.read_fastq_sequences("/var/seq_data/Chazy/515_806_SIP/Pool1/pear_merged_raw-2015-07-02.assembled.fastq_screed")
# Out:
# <ScreedDB, '/var/seq_data/FungalSIP/pear_merged_raw-2014-04-24.assembled.fastq_screed'>

# %%
db = screed.ScreedDB("/var/seq_data/Chazy/515_806_SIP/Pool1/pear_merged_raw-2015-07-02.assembled.fastq_screed")

# %%
counter = 0
unassigned = 0
cnt = Counter()
fn = "/var/seq_data/Chazy/515_806_SIP/Pool1/pear_merged_raw-2015-07-02.assembled.dmult.fastq"
with open(fn, "w") as out:
    for rec in db.itervalues():
        index_concat = ir1db[rec["name"]]["sequence"] + ir2db[rec["name"]]["sequence"]
        try:
            new_name = map_d[index_concat.lower()] + "_" + str(counter) #case sensitive
        except KeyError:
            unassigned += 1
            continue
        counter += 1
        cnt[map_d[index_concat.lower()]] += 1 #case sensitive
        s, q = rec["sequence"], rec["accuracy"]
        out.write("@%s orig_name=%s\n%s\n+\n%s\n"%(new_name,rec["name"],s,q))
print "Unable to assign %s reads to samples"%unassigned

# %%
X = np.arange(len(cnt.keys()))
Y = [v for k, v in cnt.most_common()]
fig = plt.figure()
fig.set_size_inches((18,8))
ax = fig.add_subplot(111)
bars = ax.bar(X, Y, width=0.50)
xlims = ax.set_xlim((X.min(), X.max()))
xt = ax.set_xticks(X)
xtl = ax.set_xticklabels([k for k, v in cnt.most_common()], rotation=90, ha="center", size=6)

# %%
# %%bash
# grep -c "12C.PTH.D30.R4.Frac6" /var/seq_data/Chazy/pear_merged_raw-2015-07-02.assembled.dmult.fastq
# Out:
# 43208
