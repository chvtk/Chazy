# %%
import screed
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
from mpltools import style
import mpld3
#from mpld3 import plugins
#import jinja2
#from mpld3._objects import D3Line2D, D3Collection
#mpld3.disable_notebook()

# %%
style.use("ggplot")

# %%
# %matplotlib inline

# %%
ir1 = "/var/seq_data/Chazy/ITS_SIP/Pool1/Index1.fastq.gz"
ir2 = "/var/seq_data/Chazy/ITS_SIP/Pool1/Index2.fastq.gz"

# %%
screed.read_fastq_sequences(ir1)
screed.read_fastq_sequences(ir2)

# %%
ir1db = screed.ScreedDB(ir1)
ir2db = screed.ScreedDB(ir2)

# %%
df_map = pd.read_csv("data/Metadata_Pool1_ITS_copy.txt", delimiter="\t", usecols=[1,6,7], names=["SampleID","i1","i2"])
df_map
# Out:
#                   SampleID        i1        i2
# 0              Full_sample        i1        i2
# 1      13C.PTH.D7.R4_Frac5  cgagagtt  atcgtacg
# 2      13C.PTH.D7.R4_Frac6  cgagagtt  actatctg
# 3      13C.PTH.D7.R4_Frac7  cgagagtt  tagcgagt
# 4      13C.PTH.D7.R4_Frac8  cgagagtt  ctgcgtgt
# 5      13C.PTH.D7.R4_Frac9  cgagagtt  tcatcgag
# 6     13C.PTH.D7.R4_Frac10  cgagagtt  cgtgagtg
# 7     13C.PTH.D7.R4_Frac11  cgagagtt  ggatatct
# 8     13C.PTH.D7.R4_Frac12  cgagagtt  gacaccgt
# 9     13C.PTH.D7.R4_Frac13  gacatagt  atcgtacg
# 10    13C.PTH.D7.R4_Frac14  gacatagt  actatctg
# 11    13C.PTH.D7.R4_Frac15  gacatagt  tagcgagt
# 12    13C.PTH.D7.R4_Frac16  gacatagt  ctgcgtgt
# 13    13C.PTH.D7.R4_Frac17  gacatagt  tcatcgag
# 14    13C.PTH.D7.R4_Frac18  gacatagt  cgtgagtg
# 15    13C.PTH.D7.R4_Frac19  gacatagt  ggatatct
# 16    13C.PTH.D7.R4_Frac20  gacatagt  gacaccgt
# 17    13C.PTH.D7.R4_Frac21  acgctact  atcgtacg
# 18    13C.PTH.D7.R4_Frac22  acgctact  actatctg
# 19    13C.PTH.D7.R4_Frac23  acgctact  tagcgagt
# 20    13C.PTH.D7.R4_Frac24  acgctact  ctgcgtgt
# 21    13C.PTH.D7.R4_Frac25  acgctact  tcatcgag
# 22    13C.PTH.D7.R4_Frac26  acgctact  cgtgagtg
# 23    13C.PTH.D7.R4_Frac27  acgctact  ggatatct
# 24       13C.PTH.D7.R4_H2O  acgctact  gacaccgt
# 25          Mock_community  actcactg  atcgtacg
# 26     13X.NTH.D3.R4_Frac5  actcactg  actatctg
# 27     13X.NTH.D3.R4_Frac6  actcactg  tagcgagt
# 28     13X.NTH.D3.R4_Frac7  actcactg  ctgcgtgt
# 29     13X.NTH.D3.R4_Frac8  actcactg  tcatcgag
# ..                     ...       ...       ...
# 163  12C.NTH.D30.R4_Frac19  gcgtatac  tagcgagt
# 164  12C.NTH.D30.R4_Frac20  gcgtatac  ctgcgtgt
# 165  12C.NTH.D30.R4_Frac21  gcgtatac  tcatcgag
# 166  12C.NTH.D30.R4_Frac22  gcgtatac  cgtgagtg
# 167  12C.NTH.D30.R4_Frac23  gcgtatac  ggatatct
# 168  12C.NTH.D30.R4_Frac24  gcgtatac  gacaccgt
# 169  12C.NTH.D30.R4_Frac25  tgctcgta  atcgtacg
# 170  12C.NTH.D30.R4_Frac26  tgctcgta  actatctg
# 171  12C.NTH.D30.R4_Frac27  tgctcgta  tagcgagt
# 172     12C.NTH.D30.R4_H2O  tgctcgta  ctgcgtgt
# 173    13C.NTH.D7.R4_Frac5  tgctcgta  tcatcgag
# 174    13C.NTH.D7.R4_Frac6  tgctcgta  cgtgagtg
# 175    13C.NTH.D7.R4_Frac7  tgctcgta  ggatatct
# 176    13C.NTH.D7.R4_Frac8  tgctcgta  gacaccgt
# 177    13C.NTH.D7.R4_Frac9  aacgctga  atcgtacg
# 178   13C.NTH.D7.R4_Frac10  aacgctga  actatctg
# 179   13C.NTH.D7.R4_Frac11  aacgctga  tagcgagt
# 180   13C.NTH.D7.R4_Frac12  aacgctga  ctgcgtgt
# 181   13C.NTH.D7.R4_Frac13  aacgctga  tcatcgag
# 182   13C.NTH.D7.R4_Frac14  aacgctga  cgtgagtg
# 183   13C.NTH.D7.R4_Frac15  aacgctga  ggatatct
# 184   13C.NTH.D7.R4_Frac16  aacgctga  gacaccgt
# 185   13C.NTH.D7.R4_Frac17  cgtagcga  atcgtacg
# 186   13C.NTH.D7.R4_Frac18  cgtagcga  actatctg
# 187   13C.NTH.D7.R4_Frac19  cgtagcga  tagcgagt
# 188   13C.NTH.D7.R4_Frac20  cgtagcga  ctgcgtgt
# 189   13C.NTH.D7.R4_Frac21  cgtagcga  tcatcgag
# 190   13C.NTH.D7.R4_Frac22  cgtagcga  cgtgagtg
# 191   13C.NTH.D7.R4_Frac23  cgtagcga  ggatatct
# 192   13C.NTH.D7.R4_Frac24  cgtagcga  gacaccgt
#
# [193 rows x 3 columns]

# %%
map_d = dict(map(lambda x: (x[0] + x[1], x[2]), zip(df_map.i1, df_map.i2, df_map.SampleID)))
print map_d.keys()[10], map_d[map_d.keys()[10]]
# Out:
# actcactgggatatct 13X.NTH.D3.R4_Frac10

# %%
print map_d
# Out:
# {'tgagtacgactatctg': '13X.NTH.D3.R4_Frac13', 'gatctacgcgtgagtg': '13X.NTH.D7.R4_Frac15', 'tatagcgagacaccgt': '13C.PTH.D30.R4_Frac25', 'gtaacgagcgtgagtg': '13X.NTH.D7.R4_Frac23', 'gtctatgactgcgtgt': '13C.PTH.D30.R4_Frac13', 'ctcgactttcatcgag': '12C.NTH.D7.R4_Frac6', 'tctctatgggatatct': '13X.NTH.D7.R4_Frac8', 'gtaacgagctgcgtgt': '13X.NTH.D7.R4_Frac21', 'tagtctccggatatct': '13C.PTH.D14.R4_Frac9', 'tatagcgaactatctg': '13C.PTH.D30.R4_Frac19', 'actcactgggatatct': '13X.NTH.D3.R4_Frac10', 'tagcagctactatctg': '12C.NTH.D7.R4_Frac19', 'tatagcgatcatcgag': '13C.PTH.D30.R4_Frac22', 'tagtctccatcgtacg': '13X.NTH.D3.R4_Frac28', 'atagtacccgtgagtg': '12C.NTH.D30.R4_Frac14', 'tgctcgtacgtgagtg': '13C.NTH.D7.R4_Frac6', 'acgctacttcatcgag': '13C.PTH.D7.R4_Frac25', 'acgctactctgcgtgt': '13C.PTH.D7.R4_Frac24', 'ctgcgtagactatctg': '13X.NTH.D3.R4_Frac21', 'tagcagctctgcgtgt': '12C.NTH.D7.R4_Frac21', 'actacgaccgtgagtg': '13C.PTH.D14.R4_Frac24', 'ctcgacttctgcgtgt': '12
R4_Frac23', 'ctcgacttatcgtacg': '13C.PTH.D30.R4_Frac26', 'cgagcgacgacaccgt': '13C.PTH.D14.R4_Frac18', 'atagtacctagcgagt': '12C.NTH.D30.R4_Frac11', 'cgaagtatggatatct': '12C.NTH.D7.R4_Frac16', 'i1i2': 'Full_sample', 'gtctgctactgcgtgt': '13C.PTH.D30.R4_Frac5', 'gcgtatacggatatct': '12C.NTH.D30.R4_Frac23', 'gtaacgagactatctg': '13X.NTH.D7.R4_Frac19', 'cgaagtatcgtgagtg': '12C.NTH.D7.R4_Frac15', 'gcgtatactcatcgag': '12C.NTH.D30.R4_Frac21', 'atagtacctcatcgag': '12C.NTH.D30.R4_Frac13', 'gtctatgatagcgagt': '13C.PTH.D30.R4_Frac12', 'gacatagtggatatct': '13C.PTH.D7.R4_Frac19', 'gtctgctaggatatct': '13C.PTH.D30.R4_Frac8', 'actacgacatcgtacg': '13C.PTH.D14.R4_Frac19', 'acgctacttagcgagt': '13C.PTH.D7.R4_Frac23', 'gcgtataccgtgagtg': '12C.NTH.D30.R4_Frac22', 'acgtgcgctagcgagt': '13X.NTH.D7.R4_H2O', 'tatagcgatagcgagt': '13C.PTH.D30.R4_Frac20', 'tatagc ...

# %%
#screed.read_fastq_sequences("/var/seq_data/Chazy/ITS_SIP/Pool1/pear_merged_raw-2015-08-28.assembled.fastq_screed")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-b3ea6ff4a64d> in <module>()
# ----> 1 screed.read_fastq_sequences("/var/seq_data/Chazy/ITS_SIP/Pool1/pear_merged_raw-2015-08-28.assembled.fastq_screed")
#
# /opt/anaconda/lib/python2.7/site-packages/screed/seqparse.pyc in read_fastq_sequences(filename)
#      26     """
#      27     # Will raise an exception if the file doesn't exist
# ---> 28     iterfunc = openscreed.open(filename, parse_description=True)
#      29
#      30     # Create the screed db
#
# /opt/anaconda/lib/python2.7/site-packages/screed/openscreed.pyc in __init__(self, filename, *args, **kwargs)
#      46     def __init__(self, filename, *args, **kwargs):
#      47         self.sequencefile = None
# ---> 48         self.iter_fn = self.open_reader(filename, *args, **kwargs)
#      49         if self.iter_fn:
#      50             self.__name__ = self.iter_fn.__name__
#
# /opt/anaconda/lib/python2.7/site-packages/screed/openscreed.pyc in open_reader(self, filename, *args, **kwargs)
#     102
#     103         if iter_fn is None:
# --> 104             raise ValueError("unknown file format for '%s'" % filename)
#     105
#     106         self.sequencefile = sequencefile
#
# ValueError: unknown file format for '/var/seq_data/Chazy/ITS_SIP/Pool1/pear_merged_raw-2015-08-28.assembled.fastq_screed'

# %%
db = screed.ScreedDB("/var/seq_data/Chazy/ITS_SIP/Pool1/pear_merged_raw-2015-08-28.assembled.fastq_screed")

# %%
counter = 0
unassigned = 0
cnt = Counter()
fn = "/var/seq_data/Chazy/ITS_SIP/Pool1/pear_merged_raw-2015-08-28.assembled.dmult.fastq"
with open(fn, "w") as out:
    for rec in db.itervalues():
        index_concat = ir1db[rec["name"]]["sequence"] + ir2db[rec["name"]]["sequence"]
        try:
            new_name = map_d[index_concat.lower()] + "_" + str(counter) #case sensitive
        except KeyError:
            unassigned += 1
            continue
        counter += 1
        cnt[map_d[index_concat.lower()]] += 1 #case sensitive
        s, q = rec["sequence"], rec["accuracy"]
        out.write("@%s orig_name=%s\n%s\n+\n%s\n"%(new_name,rec["name"],s,q))
print "Unable to assign %s reads to samples"%unassigned

# %%
X = np.arange(len(cnt.keys()))
Y = [v for k, v in cnt.most_common()]
fig = plt.figure()
fig.set_size_inches((18,8))
ax = fig.add_subplot(111)
bars = ax.bar(X, Y, width=0.50)
xlims = ax.set_xlim((X.min(), X.max()))
xt = ax.set_xticks(X)
xtl = ax.set_xticklabels([k for k, v in cnt.most_common()], rotation=90, ha="center", size=6)
