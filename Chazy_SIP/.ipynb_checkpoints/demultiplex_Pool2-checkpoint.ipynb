# %%
import screed
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
from mpltools import style
import mpld3
#from mpld3 import plugins
#import jinja2
#from mpld3._objects import D3Line2D, D3Collection
#mpld3.disable_notebook()

# %%
style.use("ggplot")

# %%
# %matplotlib inline

# %%
ir1 = "/var/seq_data/Chazy/515_806_SIP/Pool1/Index1.fastq.gz"
ir2 = "/var/seq_data/Chazy/515_806_SIP/Pool1/Index2.fastq.gz"

# %%
screed.read_fastq_sequences(ir1)
screed.read_fastq_sequences(ir2)
# Out:
# <ScreedDB, '/var/seq_data/Chazy/515_806_SIP/Pool1/Index2.fastq.gz_screed'>

# %%
ir1db = screed.ScreedDB(ir1)
ir2db = screed.ScreedDB(ir2)

# %%
df_map = pd.read_csv("data/Metadata_ChazySIP_pool1_515806.txt", delimiter="\t", usecols=[1,6,7], names=["SampleID","i1","i2"])
df_map
# Out:
#                   SampleID         i1         i2
# 0              Full_sample  Rev_index  Fwd_index
# 1     12C.PTH.D30.R4_Frac6   cgagagtt   atcgtacg
# 2     12C.PTH.D30.R4_Frac7   cgagagtt   actatctg
# 3     12C.PTH.D30.R4_Frac8   cgagagtt   tagcgagt
# 4     12C.PTH.D30.R4_Frac9   cgagagtt   ctgcgtgt
# 5    12C.PTH.D30.R4_Frac10   cgagagtt   tcatcgag
# 6    12C.PTH.D30.R4_Frac11   cgagagtt   cgtgagtg
# 7    12C.PTH.D30.R4_Frac12   cgagagtt   ggatatct
# 8    12C.PTH.D30.R4_Frac13   cgagagtt   gacaccgt
# 9    12C.PTH.D30.R4_Frac14   gacatagt   atcgtacg
# 10   12C.PTH.D30.R4_Frac15   gacatagt   actatctg
# 11   12C.PTH.D30.R4_Frac16   gacatagt   tagcgagt
# 12   12C.PTH.D30.R4_Frac17   gacatagt   ctgcgtgt
# 13   12C.PTH.D30.R4_Frac18   gacatagt   tcatcgag
# 14   12C.PTH.D30.R4_Frac19   gacatagt   cgtgagtg
# 15   12C.PTH.D30.R4_Frac20   gacatagt   ggatatct
# 16   12C.PTH.D30.R4_Frac21   gacatagt   gacaccgt
# 17   12C.PTH.D30.R4_Frac22   acgctact   atcgtacg
# 18   12C.PTH.D30.R4_Frac23   acgctact   actatctg
# 19   12C.PTH.D30.R4_Frac24   acgctact   tagcgagt
# 20   12C.PTH.D30.R4_Frac25   acgctact   ctgcgtgt
# 21   12C.PTH.D30.R4_Frac26   acgctact   tcatcgag
# 22   12C.PTH.D30.R4_Frac27   acgctact   cgtgagtg
# 23   12C.PTH.D30.R4_Frac28   acgctact   ggatatct
# 24         H2O_neg_control   acgctact   gacaccgt
# 25     13X.NTH.D3.R4_Frac5   actcactg   atcgtacg
# 26     13X.NTH.D3.R4_Frac6   actcactg   actatctg
# 27     13X.NTH.D3.R4_Frac7   actcactg   tagcgagt
# 28     13X.NTH.D3.R4_Frac8   actcactg   ctgcgtgt
# 29     13X.NTH.D3.R4_Frac9   actcactg   tcatcgag
# ..                     ...        ...        ...
# 171   12C.NTH.D3.R4_Frac25   gtctgcta   agagtcac
# 172   12C.NTH.D3.R4_Frac26   gtctgcta   tacgagac
# 173   12C.NTH.D3.R4_Frac27   gtctgcta   acgtctcg
# 174   12C.NTH.D3.R4_Frac28   gtctgcta   tcgacgag
# 175        H2O_neg_control   gtctgcta   gatcgtgt
# 176    12C.PTH.D3.R4_Frac5   gtctgcta   gtcagata
# 177    12C.PTH.D3.R4_Frac6   gtctatga   ctactata
# 178    12C.PTH.D3.R4_Frac7   gtctatga   cgttacta
# 179    12C.PTH.D3.R4_Frac8   gtctatga   agagtcac
# 180    12C.PTH.D3.R4_Frac9   gtctatga   tacgagac
# 181   12C.PTH.D3.R4_Frac10   gtctatga   acgtctcg
# 182   12C.PTH.D3.R4_Frac11   gtctatga   tcgacgag
# 183   12C.PTH.D3.R4_Frac12   gtctatga   gatcgtgt
# 184   12C.PTH.D3.R4_Frac13   gtctatga   gtcagata
# 185   12C.PTH.D3.R4_Frac14   tatagcga   ctactata
# 186   12C.PTH.D3.R4_Frac15   tatagcga   cgttacta
# 187   12C.PTH.D3.R4_Frac16   tatagcga   agagtcac
# 188   12C.PTH.D3.R4_Frac17   tatagcga   tacgagac
# 189   12C.PTH.D3.R4_Frac18   tatagcga   acgtctcg
# 190   12C.PTH.D3.R4_Frac19   tatagcga   tcgacgag
# 191   12C.PTH.D3.R4_Frac20   tatagcga   gatcgtgt
# 192   12C.PTH.D3.R4_Frac21   tatagcga   gtcagata
# 193                    NaN        NaN        NaN
# 194                    NaN        NaN        NaN
# 195                    NaN        NaN        NaN
# 196                    NaN        NaN        NaN
# 197                    NaN        NaN        NaN
# 198                    NaN        NaN        NaN
# 199                    NaN        NaN        NaN
# 200                    NaN        NaN        NaN
#
# [201 rows x 3 columns]

# %%
map_d = dict(map(lambda x: (x[0] + x[1], x[2]), zip(df_map.i1, df_map.i2, df_map.SampleID)))
print map_d.keys()[10], map_d[map_d.keys()[10]]
# Out:
# actcactgggatatct 13X.NTH.D3.R4_Frac11

# %%
print map_d
# Out:
# {nan: nan, 'tgagtacgactatctg': '13X.NTH.D3.R4_Frac14', 'tatagcgagacaccgt': '13X.PTH.D7.R4_Frac25', nan: nan, 'tatagcgatacgagac': '12C.PTH.D3.R4_Frac17', 'actacgacgatcgtgt': '12C.NTH.D3.R4_Frac21', 'gtctatgactgcgtgt': '13X.PTH.D7.R4_Frac13', nan: nan, 'tagtctccggatatct': '13C.NTH.D14.R4_Frac9', 'tatagcgaactatctg': '13X.PTH.D7.R4_Frac19', 'actcactgggatatct': '13X.NTH.D3.R4_Frac11', 'tagtctcctacgagac': '12C.PTH.D1.R4_Frac27', 'cgagcgactcgacgag': '12C.NTH.D3.R4_Frac12', 'tatagcgatcatcgag': '13X.PTH.D7.R4_Frac22', 'tagtctccatcgtacg': '13X.NTH.D3.R4_Frac29', 'cgagcgacacgtctcg': '12C.NTH.D3.R4_Frac11', 'tagtctccacgtctcg': '12C.PTH.D1.R4_Frac28', 'acgctacttcatcgag': '12C.PTH.D30.R4_Frac26', 'acgct
gtctatgaactatctg': '13X.PTH.D7.R4_Frac11', 'ctgcgtagagagtcac': '12C.PTH.D1.R4_Frac18', 'cgagcgacctgcgtgt': '13C.NTH.D14.R4_Frac14', 'gtctatgatacgagac': '12C.PTH.D3.R4_Frac9', 'gacatagtgtcagata': '13C.PTH.D14.R4_Frac16', 'actacgacgtcagata': '12C.NTH.D3.R4_Frac22', 'cgagcgacgacaccgt': '13C.NTH.D14.R4_Frac18', 'tatagcgatcgacgag': '12C.PTH.D3.R4_Frac19', 'actcactggtcagata': '12C.PTH.D1.R4_Frac7', 'gacatagtgatcgtgt': '13C.PTH.D14.R4_Frac15', 'gtctgctactgcgtgt': '13X.PTH.D7.R4_Frac5', 'cgagcgactacgagac': '12C.NTH.D3.R4_Frac10', 'gtctgctaagagtcac': '12C.NTH.D3.R4_Frac25', 'gtctatgatagcgagt': '13X.PTH.D7.R4_Frac12', 'gacatagtggatatct': '12C.PTH.D30.R4_Frac20', 'gtctgctaggatatct': '13X.PTH.D7.R4_Frac8', 'actacgacatcgtacg': '13C.NTH.D14.R4_Frac19', 'acgctacttagcgagt': '12C.PTH.D30.R4_Frac24', 'actcactgtcgacgag': '12C.PTH.D1.R4_Frac5', 'acgctactctactata': '13C.PTH.D14.R4_Frac17', 'tatagcgatagcgagt': '13X.PTH.D7.R4_Frac20', 'tatagcgaggatatct': '13X.PTH.D7.R4_Frac24', 'gtctgctaactatctg': '13C.NTH.D14.R4_Frac28', 'acgctactactatctg': '12C.PTH.D30.R4_Frac23', 'actacgacggatatct': '13C.NTH.D14.R4_Frac25', 'acgctactcgtgagtg': '12C.PTH.D30.R4_Frac27', 'cgagagttgtcagata': '13C.PTH.D14.R4_Frac8', 'tgagtacgctgcgtgt': '13X.NTH.D3.R4_Frac1 ...

# %%
screed.read_fastq_sequences("/var/seq_data/Chazy/515_806_SIP/Pool1/pear_merged_raw-2015-07-02.assembled.fastq_screed")
# Out:
# <ScreedDB, '/var/seq_data/FungalSIP/pear_merged_raw-2014-04-24.assembled.fastq_screed'>

# %%
db = screed.ScreedDB("/var/seq_data/Chazy/515_806_SIP/Pool1/pear_merged_raw-2015-07-02.assembled.fastq_screed")

# %%
counter = 0
unassigned = 0
cnt = Counter()
fn = "/var/seq_data/Chazy/pear_merged_raw-2015-07-02.assembled.dmult.fastq"
with open(fn, "w") as out:
    for rec in db.itervalues():
        index_concat = ir1db[rec["name"]]["sequence"] + ir2db[rec["name"]]["sequence"]
        try:
            new_name = map_d[index_concat.lower()] + "_" + str(counter) #case sensitive
        except KeyError:
            unassigned += 1
            continue
        counter += 1
        cnt[map_d[index_concat.lower()]] += 1 #case sensitive
        s, q = rec["sequence"], rec["accuracy"]
        out.write("@%s orig_name=%s\n%s\n+\n%s\n"%(new_name,rec["name"],s,q))
print "Unable to assign %s reads to samples"%unassigned
# Out:
# Unable to assign 1734369 reads to samples

# %%
X = np.arange(len(cnt.keys()))
Y = [v for k, v in cnt.most_common()]
fig = plt.figure()
fig.set_size_inches((18,8))
ax = fig.add_subplot(111)
bars = ax.bar(X, Y, width=0.50)
xlims = ax.set_xlim((X.min(), X.max()))
xt = ax.set_xticks(X)
xtl = ax.set_xticklabels([k for k, v in cnt.most_common()], rotation=90, ha="center", size=6)

# %%
# %%bash
# grep -c "H2O_neg_control" /var/seq_data/Chazy/pear_merged_raw-2015-07-02.assembled.dmult.fastq
# Out:
# 41392
