# %%
import screed
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
from mpltools import style
import mpld3
#from mpld3 import plugins
#import jinja2
#from mpld3._objects import D3Line2D, D3Collection
#mpld3.disable_notebook()

# %%
style.use("ggplot")

# %%
# %matplotlib inline

# %%
ir1 = "/var/seq_data/Chazy/515_806_SIP/Pool2/Index1.fastq"
ir2 = "/var/seq_data/Chazy/515_806_SIP/Pool2/Index2.fastq"

# %%
screed.read_fastq_sequences(ir1)
screed.read_fastq_sequences(ir2)
# Out:
# <ScreedDB, '/var/seq_data/Chazy/515_806_SIP/Pool2/Index2.fastq_screed'>

# %%
ir1db = screed.ScreedDB(ir1)
ir2db = screed.ScreedDB(ir2)

# %%
df_map = pd.read_csv("data/Metadata_ChazySIP_pool2_515806.txt", delimiter="\t", usecols=[1,6,7], names=["SampleID","i1","i2"])
df_map
# Out:
#                   SampleID         i1         i2
# 0              Full_sample  Rev_index  Fwd_index
# 1     12C.PTH.D3.R4_Frac22   cgagagtt   atcgtacg
# 2     12C.PTH.D3.R4_Frac23   cgagagtt   actatctg
# 3     12C.PTH.D3.R4_Frac24   cgagagtt   tagcgagt
# 4     12C.PTH.D3.R4_Frac25   cgagagtt   ctgcgtgt
# 5     12C.PTH.D3.R4_Frac26   cgagagtt   tcatcgag
# 6     12C.PTH.D3.R4_Frac27   cgagagtt   cgtgagtg
# 7     12C.PTH.D3.R4_Frac28   cgagagtt   ggatatct
# 8        12C.PTH.D3.R4.H2O   cgagagtt   gacaccgt
# 9     13X.PTH.D14.R4_Frac6   gacatagt   atcgtacg
# 10    13X.PTH.D14.R4_Frac7   gacatagt   actatctg
# 11    13X.PTH.D14.R4_Frac8   gacatagt   tagcgagt
# 12    13X.PTH.D14.R4_Frac9   gacatagt   ctgcgtgt
# 13   13X.PTH.D14.R4_Frac10   gacatagt   tcatcgag
# 14   13X.PTH.D14.R4_Frac11   gacatagt   cgtgagtg
# 15   13X.PTH.D14.R4_Frac12   gacatagt   ggatatct
# 16   13X.PTH.D14.R4_Frac13   gacatagt   gacaccgt
# 17   13X.PTH.D14.R4_Frac14   acgctact   atcgtacg
# 18   13X.PTH.D14.R4_Frac15   acgctact   actatctg
# 19   13X.PTH.D14.R4_Frac16   acgctact   tagcgagt
# 20   13X.PTH.D14.R4_Frac17   acgctact   ctgcgtgt
# 21   13X.PTH.D14.R4_Frac18   acgctact   tcatcgag
# 22   13X.PTH.D14.R4_Frac19   acgctact   cgtgagtg
# 23   13X.PTH.D14.R4_Frac20   acgctact   ggatatct
# 24   13X.PTH.D14.R4_Frac21   acgctact   gacaccgt
# 25   13X.PTH.D14.R4_Frac22   actcactg   atcgtacg
# 26   13X.PTH.D14.R4_Frac23   actcactg   actatctg
# 27   13X.PTH.D14.R4_Frac24   actcactg   tagcgagt
# 28   13X.PTH.D14.R4_Frac25   actcactg   ctgcgtgt
# 29   13X.PTH.D14.R4_Frac26   actcactg   tcatcgag
# ..                     ...        ...        ...
# 163   13X.NTH.D7.R4_Frac13   actacgac   agagtcac
# 164   13X.NTH.D7.R4_Frac14   actacgac   tacgagac
# 165   13X.NTH.D7.R4_Frac15   actacgac   acgtctcg
# 166   13X.NTH.D7.R4_Frac16   actacgac   tcgacgag
# 167   13X.NTH.D7.R4_Frac17   actacgac   gatcgtgt
# 168   13X.NTH.D7.R4_Frac18   actacgac   gtcagata
# 169   13X.NTH.D7.R4_Frac19   gtctgcta   ctactata
# 170   13X.NTH.D7.R4_Frac20   gtctgcta   cgttacta
# 171   13X.NTH.D7.R4_Frac21   gtctgcta   agagtcac
# 172   13X.NTH.D7.R4_Frac22   gtctgcta   tacgagac
# 173   13X.NTH.D7.R4_Frac23   gtctgcta   acgtctcg
# 174   13X.NTH.D7.R4_Frac24   gtctgcta   tcgacgag
# 175   13X.NTH.D7.R4_Frac25   gtctgcta   gatcgtgt
# 176   13X.NTH.D7.R4_Frac26   gtctgcta   gtcagata
# 177   13X.NTH.D7.R4_Frac27   gtctatga   ctactata
# 178      13X.NTH.D7.R4_H2O   gtctatga   cgttacta
# 179   12C.NTH.D30.R4_Frac4   gtctatga   agagtcac
# 180   12C.NTH.D30.R4_Frac5   gtctatga   tacgagac
# 181   12C.NTH.D30.R4_Frac6   gtctatga   acgtctcg
# 182   12C.NTH.D30.R4_Frac7   gtctatga   tcgacgag
# 183   12C.NTH.D30.R4_Frac8   gtctatga   gatcgtgt
# 184   12C.NTH.D30.R4_Frac9   gtctatga   gtcagata
# 185  12C.NTH.D30.R4_Frac10   tatagcga   ctactata
# 186  12C.NTH.D30.R4_Frac11   tatagcga   cgttacta
# 187  12C.NTH.D30.R4_Frac12   tatagcga   agagtcac
# 188  12C.NTH.D30.R4_Frac13   tatagcga   tacgagac
# 189  12C.NTH.D30.R4_Frac14   tatagcga   acgtctcg
# 190  12C.NTH.D30.R4_Frac15   tatagcga   tcgacgag
# 191  12C.NTH.D30.R4_Frac16   tatagcga   gatcgtgt
# 192  12C.NTH.D30.R4_Frac17   tatagcga   gtcagata
#
# [193 rows x 3 columns]

# %%
map_d = dict(map(lambda x: (x[0] + x[1], x[2]), zip(df_map.i1, df_map.i2, df_map.SampleID)))
print map_d.keys()[10], map_d[map_d.keys()[10]]
# Out:
# tatagcgatcatcgag 13X.NTH.D14.R4_Frac16

# %%
print map_d
# Out:
# {'tgagtacgactatctg': '13C.PTH.D3.R4_Frac6', 'tatagcgagacaccgt': '13X.NTH.D14.R4_Frac19', 'tatagcgatacgagac': '12C.NTH.D30.R4_Frac13', 'actacgacgatcgtgt': '13X.NTH.D7.R4_Frac17', 'gtctatgactgcgtgt': '13X.NTH.D14.R4_Frac7', 'tagtctccggatatct': '13C.PTH.D3.R4_Frac27', 'tatagcgaactatctg': '13X.NTH.D14.R4_Frac13', 'actcactgggatatct': '13X.PTH.D14.R4_Frac28', 'tagtctcctacgagac': '12C.NTH.D7.R4_Frac22', 'cgagcgactcgacgag': '13X.NTH.D7.R4_Frac8', 'tatagcgatcatcgag': '13X.NTH.D14.R4_Frac16', 'tagtctccatcgtacg': '13C.PTH.D3.R4_Frac21', 'cgagcgacacgtctcg': '13X.NT
 'cgagcgacgatcgtgt': '13X.NTH.D7.R4_Frac9', 'gtctatgacgttacta': '13X.NTH.D7.R4_H2O', 'gtctatgaactatctg': '13X.NTH.D14.R4_Frac5', 'ctgcgtagagagtcac': '12C.NTH.D7.R4_Frac13', 'cgagcgacctgcgtgt': '13X.PTH.D1.R4_Frac8', 'gtctatgatacgagac': '12C.NTH.D30.R4_Frac5', 'gacatagtgtcagata': '13C.PTH.D30.R4_Frac10', 'actacgacgtcagata': '13X.NTH.D7.R4_Frac18', 'cgagcgacgacaccgt': '13X.PTH.D1.R4_Frac12', 'tatagcgatcgacgag': '12C.NTH.D30.R4_Frac15', 'actcactggtcagata': '13C.PTH.D30.R4_Frac26', 'gacatagtgatcgtgt': '13C.PTH.D30.R4_Frac9', 'gtctgctactgcgtgt': '13X.PTH.D1.R4_Frac24', 'cgagcgactacgagac': '13X.NTH.D7.R4_Frac6', 'gtctgctaagagtcac': '13X.NTH.D7.R4_Frac21', 'gtctatgatagcgagt': '13X.NTH.D14.R4_Frac6', 'gacatagtggatatct': '13X.PTH.D14.R4_Frac12', 'gtctgctaggatatct': '13X.PTH.D1.R4_Frac27', 'actacgacatcgtacg': '13X.PTH.D1.R4_Frac13', 'acgctacttagcgagt': '13X.PTH.D14.R4_Frac16', 'actcactgtcgacgag': '13C.PTH.D30.R4_Frac24', 'acgctactctactata': '13C.PTH.D30.R4_Frac11', 'tatagcgatagcgagt': '13X.NTH.D14.R4_Frac14', 'tatagcgaggatatct': '13X.NTH.D14.R4_Frac18', 'gtctgctaactatctg': '13X.PTH.D1.R4_Frac22', 'acgctactactatctg': '13X.PTH.D14.R4_Frac15', 'actacgacggatatct': '13X.PTH.D1.R4_Frac19', 'acgctactcgtgagtg': '13X.PTH.D14.R4_Frac19', 'cgagagttgtcagata': '13X.NTH.D14.R4_Frac27', 'tgagtacgctgcgtgt': '13C.PTH.D3.R4_Frac8', 'actcactgactatctg': '13X.PT ...

# %%
screed.read_fastq_sequences("/var/seq_data/Chazy/515_806_SIP/Pool2/pear_merged_raw-2015-08-15.assembled.fastq_screed")
# Out:
# <ScreedDB, '/var/seq_data/FungalSIP/pear_merged_raw-2014-04-24.assembled.fastq_screed'>

# %%
db = screed.ScreedDB("/var/seq_data/Chazy/515_806_SIP/Pool2/pear_merged_raw-2015-08-15.assembled.fastq_screed")

# %%
counter = 0
unassigned = 0
cnt = Counter()
fn = "/var/seq_data/Chazy/515_806_SIP/Pool2/pear_merged_raw-2015-08-15.assembled.dmult.fastq"
with open(fn, "w") as out:
    for rec in db.itervalues():
        index_concat = ir1db[rec["name"]]["sequence"] + ir2db[rec["name"]]["sequence"]
        try:
            new_name = map_d[index_concat.lower()] + "_" + str(counter) #case sensitive
        except KeyError:
            unassigned += 1
            continue
        counter += 1
        cnt[map_d[index_concat.lower()]] += 1 #case sensitive
        s, q = rec["sequence"], rec["accuracy"]
        out.write("@%s orig_name=%s\n%s\n+\n%s\n"%(new_name,rec["name"],s,q))
print "Unable to assign %s reads to samples"%unassigned
# Out:
# Unable to assign 1299617 reads to samples

# %%
X = np.arange(len(cnt.keys()))
Y = [v for k, v in cnt.most_common()]
fig = plt.figure()
fig.set_size_inches((18,8))
ax = fig.add_subplot(111)
bars = ax.bar(X, Y, width=0.50)
xlims = ax.set_xlim((X.min(), X.max()))
xt = ax.set_xticks(X)
xtl = ax.set_xticklabels([k for k, v in cnt.most_common()], rotation=90, ha="center", size=6)
