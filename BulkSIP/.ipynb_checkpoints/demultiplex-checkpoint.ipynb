# %%
import screed
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
from mpltools import style
import mpld3
from mpld3 import plugins
import jinja2
#from mpld3._objects import D3Line2D, D3Collection
mpld3.disable_notebook()

# %%
style.use("ggplot")

# %%
# %matplotlib inline

# %%
ir1 = "/var/seq_data/Chazy/SIP_bulk/ChazySIP_bulk_index1.fastq"
ir2 = "/var/seq_data/Chazy/SIP_bulk/ChazySIP_bulk_index2.fastq.gz"

# %%
screed.read_fastq_sequences(ir1)
screed.read_fastq_sequences(ir2)

# %%
ir1db = screed.ScreedDB(ir1)
ir2db = screed.ScreedDB(ir2)

# %%
df_map = pd.read_csv("data/Chazy_BulkSIP_mapping.txt", delimiter="\t", usecols=[1,2,3], names=["SampleID","i1","i2"])
df_map
# Out:
#                SampleID        i1        i2
# 0                Sample      i1_r      i2_f
# 1     12C.NTH.Day1.Rep2  CGAGAGTT  ATCGTACG
# 2    12C.NTH.Day14.Rep4  CGAGAGTT  ACTATCTG
# 3     13X.NTH.Day1.Rep2  CGAGAGTT  TAGCGAGT
# 4     13X.PTH.Day7.Rep4  CGAGAGTT  CTGCGTGT
# 5     12C.PTH.Day7.Rep4  CGAGAGTT  TCATCGAG
# 6    13X.NTH.Day14.Rep2  CGAGAGTT  CGTGAGTG
# 7    13X.PTH.Day14.Rep3  CGAGAGTT  GGATATCT
# 8    13C.NTH.Day30.Rep4  CGAGAGTT  GACACCGT
# 9    12C.NTH.Day14.Rep1  GACATAGT  ATCGTACG
# 10   13X.PTH.Day14.Rep2  GACATAGT  ACTATCTG
# 11    13C.PTH.Day3.Rep2  GACATAGT  TAGCGAGT
# 12   12C.PTH.Day30.Rep3  GACATAGT  CTGCGTGT
# 13   12C.NTH.Day14.Rep2  GACATAGT  TCATCGAG
# 14    12C.PTH.Day3.Rep3  GACATAGT  CGTGAGTG
# 15    13X.NTH.Day1.Rep4  GACATAGT  GGATATCT
# 16    13C.PTH.Day7.Rep4  GACATAGT  GACACCGT
# 17    13C.NTH.Day7.Rep4  ACGCTACT  ATCGTACG
# 18    12C.NTH.Day1.Rep4  ACGCTACT  ACTATCTG
# 19    13C.NTH.Day3.Rep3  ACGCTACT  TAGCGAGT
# 20    13X.NTH.Day3.Rep3  ACGCTACT  CTGCGTGT
# 21    12C.PTH.Day1.Rep4  ACGCTACT  TCATCGAG
# 22    13X.PTH.Day3.Rep4  ACGCTACT  CGTGAGTG
# 23   13C.NTH.Day14.Rep4  ACGCTACT  GGATATCT
# 24   13C.NTH.Day30.Rep1  ACGCTACT  GACACCGT
# 25   13X.PTH.Day14.Rep4  ACTCACTG  ATCGTACG
# 26    13X.NTH.Day1.Rep3  ACTCACTG  ACTATCTG
# 27   13C.NTH.Day30.Rep2  ACTCACTG  TAGCGAGT
# 28    13C.NTH.Day3.Rep4  ACTCACTG  CTGCGTGT
# 29   13C.NTH.Day14.Rep3  ACTCACTG  TCATCGAG
# ..                  ...       ...       ...
# 83    12C.PTH.Day7.Rep1  GTCTATGA  TAGCGAGT
# 84    12C.PTH.Day1.Rep1  GTCTATGA  CTGCGTGT
# 85   13C.PTH.Day30.Rep2  GTCTATGA  TCATCGAG
# 86    13C.PTH.Day7.Rep3  GTCTATGA  CGTGAGTG
# 87    12C.NTH.Day1.Rep1  GTCTATGA  GGATATCT
# 88   12C.PTH.Day30.Rep1  GTCTATGA  GACACCGT
# 89   13C.PTH.Day30.Rep3  TATAGCGA  ATCGTACG
# 90    13X.PTH.Day1.Rep4  TATAGCGA  ACTATCTG
# 91    12C.PTH.Day3.Rep4  TATAGCGA  TAGCGAGT
# 92    13X.NTH.Day3.Rep2  TATAGCGA  CTGCGTGT
# 93   12C.PTH.Day14.Rep2  TATAGCGA  TCATCGAG
# 94    13C.PTH.Day3.Rep4  TATAGCGA  CGTGAGTG
# 95    12C.PTH.Day1.Rep3  TATAGCGA  GGATATCT
# 96    12C.NTH.Day7.Rep3  TATAGCGA  GACACCGT
# 97    13X.PTH.Day3.Rep3  CGAGAGTT  CTACTATA
# 98   12C.PTH.Day14.Rep1  CGAGAGTT  CGTTACTA
# 99   12C.NTH.Day14.Rep3  CGAGAGTT  AGAGTCAC
# 100   12C.PTH.Day7.Rep3  CGAGAGTT  TACGAGAC
# 101   12C.NTH.Day3.Rep3  CGAGAGTT  ACGTCTCG
# 102   13C.NTH.Day7.Rep1  CGAGAGTT  TCGACGAG
# 103   12C.NTH.Day7.Rep4  CGAGAGTT  GATCGTGT
# 104  12C.NTH.Day30.Rep1  CGAGAGTT  GTCAGATA
# 105        H2O.NTH.Rep1  GACATAGT  CTACTATA
# 106        H2O.NTH.Rep2  GACATAGT  CGTTACTA
# 107        H2O.NTH.Rep3  GACATAGT  AGAGTCAC
# 108        H2O.NTH.Rep4  GACATAGT  TACGAGAC
# 109        H2O.PTH.Rep1  GACATAGT  ACGTCTCG
# 110        H2O.PTH.Rep2  GACATAGT  TCGACGAG
# 111        H2O.PTH.Rep3  GACATAGT  GATCGTGT
# 112        H2O.PTH.Rep4  GACATAGT  GTCAGATA
#
# [113 rows x 3 columns]

# %%
map_d = dict(map(lambda x: (x[0] + x[1], x[2]), zip(df_map.i1, df_map.i2, df_map.SampleID)))
print map_d.keys()[10], map_d[map_d.keys()[10]]
# Out:
# TGAGTACGCGTGAGTG 13X.PTH.Day7.Rep3

# %%
print map_d
# Out:
# {'TAGTCTCCCTGCGTGT': '13X.NTH.Day7.Rep2', 'CGAGAGTTAGAGTCAC': '12C.NTH.Day14.Rep3', 'ACGCTACTGACACCGT': '13C.NTH.Day30.Rep1', 'CTGCGTAGGACACCGT': '12C.NTH.Day3.Rep2', 'ACTCACTGCGTGAGTG': '12C.PTH.Day7.Rep2', 'GTCTGCTAGACACCGT': '12C.PTH.Day3.Rep2', 'ACTCACTGGGATATCT': '12C.NTH.Day7.Rep2', 'CGAGAGTTATCGTACG': '12C.NTH.Day1.Rep2', 'CGAGAGTTGTCAGATA': '12C.NTH.Day30.Rep1', 'GACATAGTCTGCGTGT': '12C.PTH.Day30.Rep3', 'TGAGTACGCGTGAGTG': '13X.PTH.Day7.Rep3', 'GACATAGTCGTTACTA': 'H2O.NTH.Rep2', 'GTCTATGATAGCGAGT': '12C.PTH.Day7.Rep1', 'CGAGCGACGACACCGT': '12C.NTH.Day30.Rep4', 'GACATAGTGATCGTGT': 'H2O.PTH.Rep3', 'GTCTATGATCATCGAG': '13C.PTH.Day30.Rep2', 'CGAGAGT
ep1', 'ACTCACTGCTGCGTGT': '13C.NTH.Day3.Rep4', 'ACTACGACTAGCGAGT': '13C.PTH.Day7.Rep2', 'GTCTATGACGTGAGTG': '13C.PTH.Day7.Rep3', 'TGAGTACGGACACCGT': '13X.NTH.Day1.Rep1', 'ACGCTACTCGTGAGTG': '13X.PTH.Day3.Rep4', 'CGAGAGTTTACGAGAC': '12C.PTH.Day7.Rep3', 'ACTACGACCGTGAGTG': '12C.NTH.Day7.Rep1', 'GACATAGTAGAGTCAC': 'H2O.NTH.Rep3', 'TGAGTACGTCATCGAG': '13C.PTH.Day30.Rep1', 'ACGCTACTTCATCGAG': '12C.PTH.Day1.Rep4', 'ACGCTACTCTGCGTGT': '13X.NTH.Day3.Rep3', 'ACTCACTGATCGTACG': '13X.PTH.Day14.Rep4', 'GTCTGCTAATCGTACG': '13X.NTH.Day3.Rep4', 'GACATAGTCGTGAGTG': '12C.PTH.Day3.Rep3', 'TATAGCGACTGCGTGT': '13X.NTH.Day3.Rep2', 'CGAGAGTTGACACCGT': '13C.NTH.Day30.Rep4', 'CTGCGTAGCGTGAGTG': '13X.PTH.Day1.Rep1', 'CGAGAGTTCTACTATA': '13X.PTH.Day3.Rep3', 'GACATAGTTCGACGAG': 'H2O.PTH.Rep2', 'GACATAGTTAGCGAGT': '13C.PTH.Day3.Rep2', 'TAGTCTCCCGTGAGTG': '13X.NTH.Day7.Rep4', 'TAGTCTCCACTATCTG': '13X.PTH.Day7.Rep1', 'TGAGTACGGGATATCT': '13C.NTH.Day3.Rep1', 'TATAGCGATCATCGAG': '12C.PTH.Day14.Rep2', 'CTGCGTAGACTATCTG': '13X.PTH.Day1.Rep2', 'CGAGAGTTTAGCGAGT': '13X.NTH.Day1.Rep2', 'GACATAGTTACGAGAC': 'H2O.NTH.Rep4', 'ACTCACTGACTATCTG': '13X.NTH.Day1.Rep3', 'GACATAGTACTATCTG': '13X.PTH.Day14.Rep2', 'TATAGCGAGACACCGT': '12C.NTH.Day7.Rep3', 'CGAGCGACTAGCGAGT': '13X.NTH.Day7.Rep3', 'TAGTCTCCTAGCGAGT': '12C.NTH.Day3.Rep4', 'CGAGAGTTCTGCGTGT': '13X.PTH.Day7.Rep4', 'GTCTATG ...

# %%
screed.read_fastq_sequences("/var/seq_data/Chazy/SIP_bulk/ChazySIP_bulk_pear_merged_raw-2015-03-02.assembled.fastq")

# %%
db = screed.ScreedDB("/var/seq_data/Chazy/SIP_bulk/ChazySIP_bulk_pear_merged_raw-2015-03-02.assembled.fastq_screed")

# %%
counter = 0
unassigned = 0
cnt = Counter()
fn = "/var/seq_data/Chazy/SIP_bulk/ChazySIP_bulk_pear_merged_raw-2014-08-29.assembled.dmult.fastq"
with open(fn, "w") as out:
    for rec in db.itervalues():
        index_concat = ir1db[rec["name"]]["sequence"] + ir2db[rec["name"]]["sequence"]
        try:
            new_name = map_d[index_concat.lower()] + "_" + str(counter) #case sensitive
        except KeyError:
            unassigned += 1
            continue
        counter += 1
        cnt[map_d[index_concat.lower()]] += 1 #case sensitive
        s, q = rec["sequence"], rec["accuracy"]
        out.write("@%s orig_name=%s\n%s\n+\n%s\n"%(new_name,rec["name"],s,q))
print "Unable to assign %s reads to samples"%unassigned

# %%
X = np.arange(len(cnt.keys()))
Y = [v for k, v in cnt.most_common()]
fig = plt.figure()
fig.set_size_inches((18,8))
ax = fig.add_subplot(111)
bars = ax.bar(X, Y, width=0.50)
xlims = ax.set_xlim((X.min(), X.max()))
xt = ax.set_xticks(X)
xtl = ax.set_xticklabels([k for k, v in cnt.most_common()], rotation=90, ha="center", size=6)
